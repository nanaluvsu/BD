# %% [markdown]
# # Manipulação de Arquivos em Python

# %%
import pandas as pd

# %% [markdown]
# ### TXT

# %%
arq = open("vendas.txt", 'r')

# %% [markdown]
# Uma vez aberto, podemos realizar a leitura do arquivo usando as funções: read(n), readline( ) ou readlines( ).
#
# A função read(n) lê até n bytes. Caso o valor não seja informado, a função lê o arquivo inteiro. A função readline( ) retorna uma string contendo a primeira linha do arquivo. Por fim, a função readlines( ) retorna uma lista de strings, sendo cada elemento uma linha do arquivo.

# %%
linhas = arq.readlines()
type(linhas)
# Out:
# list

# %%
for linha in linhas:
    print(linha)
# Out:
# 0,24,21,28,32,26,23,46,43,65
#
# 1,30,27,25,29,24,20,46,43,66
#
# 2,26,24,29,35,23,24,48,45,68
#
# 3,24,21,27,32,23,23,45,42,63
#
# 4,27,24,27,32,22,23,46,43,66
#
# 5,24,23,27,32,24,24,46,43,65
#
# 6,25,23,28,30,25,23,46,43,65
#
# 7,26,23,27,29,27,21,45,43,65
#
# 8,23,21,25,27,24,21,42,39,60
#
# 9,29,27,28,28,24,23,47,44,68
#
# 10,23,21,26,33,26,23,45,42,65
#
# 11,29,26,26,30,23,22,46,44,66
#
# 12,27,24,26,31,23,22,45,43,65
#
# 13,21,19,24,28,23,22,41,38,58
#
# 14,28,25,28,29,24,25,47,44,68
#
# 15,25,22,26,26,26,21,43,41,62
#
# 16,21,20,26,31,22,24,43,40,61
#
# 17,25,22,24,27,25,23,43,41,62
#
# 18,20,18,24,29,23,23,41,38,58
#
# 19,24,21,23,23,25,25,42,39,60
#
# 20,18,17,20,25,21,25,37,35,54
#
# 21,22,20,21,26,21,25,40,38,57
#
# 22,17,16,20,26,22,24,37,35,53
#
# 23,20,19,21,22,22,23,38,35,54
#
# 0,29,26,28,28,26,20,47,44,66
#
# 1,31,30,28,31,22,23,49,46,70
#
# 2,31,30,26,28,25,20,48,44,68
#
# 3,24,22,27,29,25,24,45,42,64
#
# 4,23,20,25,27,24,21,42,39,59
#
# 5,30,28,25,25,24,22,46,43,65
#
# 6,23,21,27,34,26,23,46,43,65
#
# 7,23,21,28,34,24,23,45,43,65
#
# 8,25,24,27,27,27,22,45,42,65
#
# 9,24,21,27,31,25,23,45,42,64
#
# 10,23,22,27,30,27,23,45,42,65
#
# 11,26,25,28,28,27,23,47,44,66
#
# 12,23,20,28,28,27,25,45,42,64
#
# 13,28,26,26,31,26,23,48,44,68
#
# 14,26,23,26,26,25,21,44,41,62
#
# 15,26,24,26,32,26,22,46,44,66
#
# 16,23,21,24,24,22,21,40,38,57
#
# 17,27,26,22,27,26,21,44,42,63
#
# 18,23,22,26,30,24,21,43,41,62
#
# 19,18,16,21,25,23,26,38,36,55
#
# 20,22,20,24,29,21,20,40,38,58
#
# 21,18,17,24,25,21,21,37,35,54
#
# 22,19,17,23,24,24,25,39,37,56
#
# 23,21,20,20,25,21,25,39,37,56
#
# 0,32,31,24,28,22,20,47,44,66
#
# 1,31,28,28,30,25,21,48,46,69
#
# 2,26,25,29,32,24,23,47,44,68
#
# 3,30,28,27,31,23,25,49,46,69
#
# 4,31,29,26,31,23,22,48,45,69
#
# 5,28,25,28,30,27,25,48,46,69
#
# 6,28,25,28,33,27,22,48,46,69
#
# 7,23,21,29,30,26,22,45,42,64
#
# 8,25,22,25,32,25,24,45,43,65
#
# 9,22,21,27,33,26,20,44,42,63
#
# 10,22,21,24,24,25,21,41,38,58
#
# 11,22,21,29,36,27,23,47,44,67
#
# 12,25,21,29,31,26,26,47,44,67
#
# 13,29,25,25,27,25,22,45,43,65
#
# 14,23,21,24,31,24,23,43,41,62
#
# 15,27,24,24,27,23,22,44,41,62
#
# 16,19,17,23,25,22,22,38,36,54
#
# 17,23,22,22,24,26,26,42,40,61
#
# 18,18,17,25,25,23,26,40,37,57
#
# 19,25,23,25,31,22,25,45,42,64
#
# 20,18,15,25,28,22,21,38,36,55
#
# 21,20,19,22,23,21,23,38,36,54
#
# 22,20,17,19,21,25,22,37,34,53
#
# 23,19,17,19,22,23,24,37,34,53
#
# 0,27,25,25,32,24,21,46,43,65
#
# 1,25,22,24,26,26,23,43,41,62
#
# 2,25,22,27,28,26,23,45,42,64
#
# 3,27,25,26,31,23,23,46,43,66
#
# 4,24,21,27,30,22,24,44,41,63
#
# 5,29,26,29,31,23,25,48,46,69
#
# 6,25,24,25,27,26,25,45,42,65
#
# 7,27,24,26,27,25,26,46,43,66
#
# 8,25,22,28,32,26,26,47,44,68
#
# 9,26,23,26,26,23,22,43,41,62
#
# 10,23,20,26,32,26,22,44,42,63
#
# 11,25,24,26,30,27,26,47,44,67
#
# 12,21,18,28,32,24,23,43,41,62
#
# 13,28,27,26,31,27,21,48,44,68
#
# 14,28,24,27,33,24,24,48,44,68
#
# 15,24,22,27,34,24,25,46,44,66
#
# 16,22,19,24,25,27,24,42,39,60
#
# 17,22,19,22,27,25,22,41,38,58
#
# 18,27,25,26,26,22,25,45,42,64
#
# 19,23,20,21,21,25,21,39,36,56
#
# 20,25,24,22,29,23,26,44,42,63
#
# 21,17,15,22,29,25,22,39,36,55
#
# 22,21,20,23,27,23,24,41,38,59
#
# 23,24,23,20,26,23,21,41,38,58
#
# 0,30,26,26,27,24,25,47,44,67
#
# 1,24,20,25,30,25,21,43,40,62
#
# 2,31,29,26,27,25,25,48,46,69
#
# 3,28,27,29,35,24,21,49,46,69
#
# 4,30,26,25,25,24,23,45,43,65
#
# 5,30,26,25,28,24,20,45,43,65
#
# 6,30,26,26,33,26,25,49,46,71
#
# 7,28,24,28,34,27,23,49,46,69
#
# 8,26,24,28,30,28,21,47,44,66
#
# 9,26,22,25,29,24,24,45,42,63
#
# 10,25,22,30,37,28,25,50,46,71
#
# 11,28,25,28,33,25,26,49,46,70
#
# 12,26,23,26,29,23,25,45,42,65
#
# 13,29,27,23,26,22,24,45,42,64
#
# 14,20,19,25,28,27,21,42,39,59
#
# 15,20,17,26,27,26,22,41,38,59
#
# 16,20,17,23,25,27,25,41,38,58
#
# 17,21,20,26,33,25,23,44,41,63
#
# 18,24,22,25,25,23,25,43,40,61
#
# 19,24,22,23,30,22,23,43,40,61
#
# 20,19,18,21,26,24,22,39,36,55
#
# 21,26,23,21,28,26,24,44,41,63
#
# 22,21,20,23,23,26,21,40,37,57
#
# 23,25,24,22,28,23,25,44,41,62
#
# 0,28,25,26,33,27,25,49,46,69
#
# 1,29,26,27,33,26,22,48,46,69
#
# 2,28,26,27,29,25,24,47,44,68
#
# 3,31,28,27,28,25,23,48,45,69
#
# 4,24,23,29,34,24,23,47,44,66
#
# 5,30,26,30,30,23,20,47,44,68
#
# 6,23,19,28,31,24,25,45,42,63
#
# 7,26,23,30,34,23,24,48,44,68
#
# 8,27,24,30,34,27,26,50,47,71
#
# 9,23,21,26,32,24,21,44,41,62
#
# 10,28,25,30,33,28,21,49,46,70
#
# 11,29,26,27,32,25,23,48,45,69
#
# 12,29,27,24,25,25,21,45,42,64
#
# 13,21,19,28,29,23,22,42,40,60
#
# 14,23,21,24,32,25,23,44,41,63
#
# 15,28,25,23,28,26,25,46,43,66
#
# 16,19,17,26,28,23,22,40,38,57
#
# 17,22,19,22,26,26,25,42,39,59
#
# 18,20,16,26,26,24,22,40,37,57
#
# 19,23,21,24,30,25,24,44,41,62
#
# 20,21,19,24,25,22,22,39,37,57
#
# 21,26,25,24,26,24,23,44,41,63
#
# 22,23,20,24,29,25,24,43,40,62
#
# 23,19,18,19,26,21,21,37,34,53
#
# 0,30,29,26,30,26,22,48,46,69
#
# 1,33,31,29,36,24,20,51,48,74
#
# 2,29,26,28,34,22,23,48,45,69
#
# 3,25,21,30,32,22,26,46,44,66
#
# 4,29,27,26,26,28,23,47,44,68
#
# 5,24,21,27,30,25,20,44,41,62
#
# 6,29,28,25,25,26,25,47,44,67
#
# 7,23,22,30,38,24,24,48,45,68
#
# 8,27,25,29,31,23,22,47,44,66
#
# 9,30,27,27,27,23,21,46,43,66
#
# 10,23,21,26,26,23,22,42,39,60
#
# 11,29,28,25,29,23,24,47,44,67
#
# 12,25,24,29,36,24,21,47,44,68
#
# 13,27,25,24,25,25,24,45,42,63
#
# 14,27,26,25,26,28,24,46,44,66
#
# 15,29,28,23,24,22,25,45,42,64
#
# 16,27,26,25,28,25,23,46,43,65
#
# 17,24,21,22,23,22,23,40,38,57
#
# 18,25,22,27,32,25,24,46,43,66
#
# 19,24,23,26,30,26,25,46,43,65
#
# 20,27,26,21,21,25,23,42,40,61
#
# 21,21,20,22,28,22,21,40,37,57
#
# 22,19,16,24,31,24,26,42,39,59
#
# 23,22,21,21,22,21,22,38,36,55
#
# 0,24,22,27,28,23,20,43,40,61
#
# 1,28,27,29,36,23,20,48,46,69
#
# 2,31,28,30,30,24,23,49,46,71
#
# 3,26,24,28,30,26,22,46,44,66
#
# 4,30,27,28,34,24,24,50,46,71
#
# 5,31,28,26,29,25,21,48,44,68
#
# 6,31,28,29,36,25,24,51,48,74
#
# 7,30,29,27,35,28,21,51,47,72
#
# 8,23,19,26,29,26,26,44,42,63
#
# 9,26,23,26,31,23,23,45,42,65
#
# 10,29,26,26,29,24,25,47,44,68
#
# 11,29,26,25,31,24,25,48,44,68
#
# 12,28,26,25,28,28,23,47,44,67
#
# 13,22,18,27,29,26,26,44,41,63
#
# 14,22,19,25,33,23,23,43,40,62
#
# 15,25,23,28,35,27,22,48,44,68
#
# 16,22,20,25,33,23,25,44,41,63
#
# 17,27,23,24,26,27,23,45,42,63
#
# 18,22,21,22,29,27,21,42,40,60
#
# 19,18,15,23,24,24,23,38,35,54
#
# 20,24,22,22,28,24,26,43,41,62
#
# 21,21,18,25,30,23,25,42,40,60
#
# 22,20,18,20,20,23,22,36,34,53
#
# 23,26,25,19,21,24,24,41,39,59
#
# 0,32,31,25,30,26,22,49,46,71
#
# 1,31,30,26,30,26,23,49,46,71
#
# 2,32,29,28,31,25,24,50,47,72
#
# 3,30,27,29,30,23,23,48,45,69
#
# 4,27,24,30,33,26,26,49,46,71
#
# 5,25,23,28,34,27,23,48,44,68
#
# 6,29,28,30,36,28,23,52,48,74
#
# 7,24,22,26,28,26,23,44,42,63
#
# 8,27,25,27,32,23,20,46,43,65
#
# 9,30,29,28,33,23,23,49,46,71
#
# 10,24,23,27,33,25,26,47,44,67
#
# 11,22,18,28,34,24,21,44,41,62
#
# 12,30,28,26,31,26,26,50,46,71
#
# 13,26,25,27,33,27,21,47,44,68
#
# 14,21,19,25,32,26,21,43,40,61
#
# 15,27,25,28,32,24,25,48,45,68
#
# 16,21,18,26,28,27,24,43,40,61
#
# 17,25,21,27,32,27,21,45,43,65
#
# 18,21,19,22,28,23,23,40,38,58
#
# 19,26,25,21,29,22,24,44,41,62
#
# 20,26,25,21,28,22,23,43,40,62
#
# 21,23,22,20,21,21,20,38,35,54
#
# 22,21,17,20,23,24,25,39,36,55
#
# 23,26,23,23,26,20,23,42,39,60
#
# 0,25,24,29,35,24,20,47,44,66
#
# 1,26,22,29,31,22,24,46,43,65
#
# 2,30,28,30,30,22,20,48,44,68
#
# 3,30,28,26,34,25,21,49,46,69
#
# 4,25,23,25,33,26,21,45,43,65
#
# 5,31,30,27,32,27,21,50,47,71
#
# 6,23,19,27,35,23,22,44,42,63
#
# 7,30,27,27,30,23,21,47,44,67
#
# 8,31,28,26,29,25,22,48,45,68
#
# 9,23,19,30,33,28,22,46,43,66
#
# 10,30,27,27,35,23,21,48,46,69
#
# 11,30,27,25,31,25,24,48,45,69
#
# 12,21,20,28,30,27,21,44,41,62
#
# 13,25,22,28,28,24,25,45,42,65
#
# 14,25,24,27,32,27,25,48,44,68
#
# 15,24,23,28,31,28,25,47,44,68
#
# 16,26,25,27,29,25,21,45,43,65
#
# 17,26,24,25,31,22,23,45,42,64
#
# 18,22,18,26,28,24,24,42,40,60
#
# 19,24,22,22,29,23,21,42,39,60
#
# 20,20,19,26,27,27,22,42,39,60
#
# 21,20,17,25,29,21,24,40,38,58
#
# 22,26,24,25,28,22,22,44,41,62
#
# 23,19,17,21,26,24,22,38,36,55
#
# 0,29,27,28,36,23,22,49,46,70
#
# 1,31,29,29,33,23,22,50,46,71
#
# 2,28,25,27,33,27,21,48,45,68
#
# 3,28,25,25,28,23,26,46,43,66
#
# 4,25,24,28,30,27,23,47,44,66
#
# 5,30,27,27,34,25,21,49,46,69
#
# 6,31,28,31,39,24,22,52,49,74
#
# 7,28,27,25,28,22,23,45,43,65
#
# 8,31,29,29,33,27,24,51,48,74
#
# 9,23,22,27,31,26,21,45,42,63
#
# 10,22,21,26,26,23,25,42,40,61
#
# 11,28,26,28,36,27,26,51,48,72
#
# 12,30,29,25,29,24,23,48,44,68
#
# 13,23,20,25,33,26,23,45,42,63
#
# 14,21,18,26,27,22,26,42,39,59
#
# 15,29,26,27,32,23,26,48,46,69
#
# 16,21,20,24,29,25,21,42,39,59
#
# 17,24,21,22,29,27,25,44,41,63
#
# 18,21,17,23,31,26,25,42,40,61
#
# 19,25,22,25,31,23,26,45,42,65
#
# 20,27,25,25,26,23,24,45,42,63
#
# 21,24,23,21,23,26,24,42,39,60
#
# 22,25,22,25,33,21,20,43,41,62
#
# 23,23,22,22,25,20,23,40,38,57
#
# 0,33,29,26,30,24,23,49,46,70
#
# 1,31,29,27,27,25,20,47,44,68
#
# 2,32,28,30,39,27,25,54,50,77
#
# 3,26,24,25,30,24,21,45,42,63
#
# 4,26,24,27,32,28,26,48,46,69
#
# 5,29,25,30,30,28,22,49,46,69
#
# 6,33,29,27,30,25,22,49,46,71
#
# 7,30,26,26,35,28,20,49,46,70
#
# 8,30,27,30,36,23,24,51,47,72
#
# 9,24,21,27,30,23,25,45,42,63
#
# 10,28,27,28,32,28,22,49,46,70
#
# 11,27,26,24,26,24,25,45,42,65
#
# 12,25,22,24,29,27,26,45,43,65
#
# 13,22,20,26,34,24,24,45,42,63
#
# 14,23,20,28,31,24,26,45,42,65
#
# 15,29,27,28,34,26,23,50,46,71
#
# 16,21,19,25,27,26,25,42,40,61
#
# 17,19,16,24,25,25,26,40,38,57
#
# 18,22,19,22,22,23,25,39,37,57
#
# 19,19,18,25,30,23,23,41,38,59
#
# 20,26,22,24,31,26,25,46,43,65
#
# 21,18,17,25,30,23,22,40,38,57
#
# 22,23,20,21,25,23,22,40,37,57
#
# 23,20,19,21,26,25,26,41,38,58
#
# 0,33,32,27,30,26,21,50,47,72
#
# 1,32,30,25,29,25,23,49,46,69
#
# 2,26,23,26,34,23,20,45,42,65
#
# 3,23,22,29,34,24,25,47,44,66
#
# 4,26,24,31,33,28,21,48,46,69
#
# 5,31,27,27,30,28,23,49,46,71
#
# 6,27,24,26,32,24,26,47,44,68
#
# 7,31,27,29,36,24,24,51,48,72
#
# 8,31,27,25,32,27,22,49,46,69
#
# 9,31,27,30,39,25,22,52,48,74
#
# 10,24,23,24,31,25,23,45,42,63
#
# 11,31,30,29,32,23,25,51,47,72
#
# 12,25,22,26,27,26,26,45,42,65
#
# 13,30,28,25,25,28,24,48,44,68
#
# 14,28,25,29,36,28,21,50,46,71
#
# 15,20,19,28,36,28,21,45,42,65
#
# 16,22,20,23,23,24,26,41,38,59
#
# 17,27,25,27,27,27,23,46,44,66
#
# 18,19,17,24,28,23,21,39,37,56
#
# 19,27,26,21,29,28,21,45,42,65
#
# 20,24,20,24,29,28,25,45,42,63
#
# 21,26,25,24,30,25,27,47,44,66
#
# 22,26,23,23,27,27,22,44,41,63
#
# 23,17,13,20,22,22,26,36,33,51
#
# 0,26,22,27,29,25,25,46,43,65
#
# 1,30,28,25,28,28,23,48,45,69
#
# 2,32,30,30,32,28,24,52,49,75
#
# 3,26,24,29,29,22,25,46,43,66
#
# 4,25,22,29,33,27,26,48,45,69
#
# 5,32,29,25,29,25,21,48,45,68
#
# 6,31,30,29,36,25,21,51,48,73
#
# 7,24,23,28,35,23,21,46,43,65
#
# 8,27,26,28,31,26,23,48,45,68
#
# 9,27,23,25,25,26,23,44,42,63
#
# 10,30,26,24,28,23,24,46,43,66
#
# 11,27,26,31,40,28,25,53,49,75
#
# 12,30,29,30,35,26,24,52,48,74
#
# 13,22,20,28,35,28,21,46,43,65
#
# 14,20,16,26,34,23,25,43,40,61
#
# 15,30,26,26,29,27,27,49,46,70
#
# 16,28,24,28,35,28,21,49,46,69
#
# 17,19,17,22,29,24,24,40,38,57
#
# 18,18,15,24,26,24,26,39,37,57
#
# 19,28,26,22,23,22,24,43,40,62
#
# 20,25,23,25,30,26,24,45,43,65
#
# 21,24,21,20,23,22,25,40,38,57
#
# 22,19,18,21,22,22,25,38,35,54
#
# 23,21,17,24,29,26,27,43,40,61
#
# 0,34,30,29,31,27,26,53,49,75
#
# 1,31,29,30,37,21,23,51,48,72
#
# 2,33,31,26,31,24,20,49,46,70
#
# 3,24,20,26,33,24,21,44,41,63
#
# 4,24,23,29,36,26,21,47,44,68
#
# 5,28,24,26,30,24,25,47,44,66
#
# 6,31,28,27,35,27,23,51,48,72
#
# 7,24,23,28,34,28,26,48,46,69
#
# 8,33,29,30,30,23,26,51,48,72
#
# 9,32,30,28,28,29,20,50,46,71
#
# 10,23,20,29,29,26,22,44,42,63
#
# 11,24,22,29,35,25,23,47,44,67
#
# 12,25,23,25,25,23,21,42,40,60
#
# 13,26,22,29,37,26,25,49,46,70
#
# 14,27,26,28,33,27,25,49,46,71
#
# 15,21,20,26,32,28,25,45,42,65
#
# 16,28,24,26,31,24,23,46,44,66
#
# 17,25,21,27,28,24,23,44,41,63
#
# 18,28,25,26,29,24,21,45,43,65
#
# 19,23,21,22,22,22,22,39,37,56
#
# 20,24,23,22,31,28,22,45,42,63
#
# 21,17,16,24,29,24,26,40,38,58
#
# 22,22,17,26,34,26,21,43,41,62
#
# 23,19,18,23,24,22,22,38,36,54
#
# 0,32,29,24,33,25,20,48,46,69
#
# 1,31,28,28,28,28,21,49,46,69
#
# 2,31,29,28,30,24,26,50,47,71
#
# 3,32,28,25,31,23,21,48,44,68
#
# 4,28,24,28,32,26,23,48,45,68
#
# 5,32,31,28,29,26,26,51,48,73
#
# 6,31,27,26,34,29,27,52,48,74
#
# 7,26,24,28,36,26,22,48,45,69
#
# 8,31,29,28,32,26,24,51,47,72
#
# 9,31,28,26,32,24,25,49,46,71
#
# 10,26,25,26,34,23,25,47,44,68
#
# 11,24,21,28,37,26,23,47,44,68
#
# 12,31,28,24,32,23,21,47,44,68
#
# 13,31,29,25,26,26,24,48,45,68
#
# 14,27,25,24,31,24,26,47,44,66
#
# 15,20,18,23,26,25,24,40,38,58
#
# 16,24,22,29,32,28,21,46,44,66
#
# 17,24,23,26,34,26,23,46,44,66
#
# 18,22,21,26,33,24,22,44,41,63
#
# 19,24,22,25,25,25,21,42,40,60
#
# 20,28,26,22,25,21,26,44,41,63
#
# 21,22,18,22,30,27,21,42,39,59
#
# 22,24,21,24,27,21,25,42,40,60
#
# 23,22,20,24,24,25,26,42,39,60
#
# 0,31,29,28,36,27,20,51,48,72
#
# 1,32,30,29,31,27,21,51,47,72
#
# 2,27,24,27,36,28,24,49,46,71
#
# 3,30,26,31,39,28,20,52,48,74
#
# 4,28,26,25,29,26,24,47,44,67
#
# 5,34,30,30,34,28,21,53,49,75
#
# 6,31,30,28,38,26,25,53,50,75
#
# 7,33,31,31,38,29,24,55,52,79
#
# 8,26,21,29,29,24,27,46,44,66
#
# 9,24,21,25,33,27,21,45,42,64
#
# 10,30,29,27,36,27,24,51,48,74
#
# 11,26,24,27,28,26,21,45,42,65
#
# 12,23,19,31,35,23,22,45,43,65
#
# 13,28,27,24,27,27,27,48,44,68
#
# 14,21,17,25,26,23,27,41,39,59
#
# 15,24,21,23,27,27,26,44,41,63
#
# 16,21,17,26,34,29,26,45,43,65
#
# 17,28,25,22,26,27,22,45,42,63
#
# 18,22,17,25,26,24,22,40,38,58
#
# 19,25,21,23,24,25,27,43,40,62
#
# 20,18,14,21,28,27,21,38,36,55
#
# 21,25,24,22,27,28,23,44,42,63
#
# 22,22,21,20,24,23,21,39,36,56
#
# 23,17,16,24,31,27,24,41,39,59
#
# 0,33,29,25,30,24,23,49,46,69
#
# 1,27,25,26,31,24,20,45,43,65
#
# 2,25,24,29,30,22,25,46,43,66
#
# 3,29,28,30,38,24,22,51,48,72
#
# 4,25,20,31,38,28,21,48,46,69
#
# 5,28,24,27,35,28,26,50,47,71
#
# 6,24,21,32,39,23,24,48,46,69
#
# 7,26,24,25,29,23,24,45,42,64
#
# 8,33,31,29,36,28,27,55,51,78
#
# 9,26,24,27,35,26,24,48,45,69
#
# 10,24,20,28,28,27,24,45,42,64
#
# 11,22,19,28,31,30,22,45,42,65
#
# 12,32,31,24,31,25,26,50,47,72
#
# 13,20,17,25,26,28,22,41,38,59
#
# 14,28,27,24,24,25,24,45,42,65
#
# 15,20,16,26,30,29,25,43,41,62
#
# 16,26,24,26,33,24,23,46,44,66
#
# 17,19,18,25,34,29,25,45,42,63
#
# 18,20,17,27,28,26,24,42,40,60
#
# 19,28,26,21,28,22,25,45,42,63
#
# 20,23,18,26,32,25,22,43,41,62
#
# 21,28,24,21,25,27,21,43,41,62
#
# 22,18,17,25,30,24,26,42,39,59
#
# 23,27,24,20,26,21,25,42,40,61
#
# 0,33,32,27,32,25,21,51,47,72
#
# 1,27,25,29,29,23,22,46,43,66
#
# 2,24,20,25,28,22,23,42,40,60
#
# 3,23,22,31,35,24,22,47,44,66
#
# 4,34,32,29,29,26,26,52,49,75
#
# 5,27,24,26,30,28,24,47,44,68
#
# 6,27,22,25,28,23,23,44,41,63
#
# 7,26,25,29,33,23,24,48,44,68
#
# 8,26,23,28,34,24,25,48,44,68
#
# 9,32,30,27,31,26,27,51,48,74
#
# 10,29,24,25,33,24,22,47,44,66
#
# 11,26,23,30,30,25,21,46,43,66
#
# 12,30,28,30,35,27,24,52,48,74
#
# 13,21,20,25,28,29,24,44,41,62
#
# 14,30,28,25,26,25,22,46,44,66
#
# 15,28,27,27,30,26,21,47,44,68
#
# 16,21,20,23,30,28,26,44,41,63
#
# 17,22,20,28,33,24,26,45,43,65
#
# 18,29,28,26,28,24,26,48,45,68
#
# 19,19,16,25,31,26,21,41,38,59
#
# 20,22,19,21,22,27,23,40,37,57
#
# 21,18,15,24,27,22,25,39,36,56
#
# 22,21,19,19,23,27,27,40,38,58
#
# 23,27,22,22,28,21,26,43,41,62
#
# 0,30,26,24,26,23,25,46,43,65
#
# 1,31,26,27,35,26,21,49,46,71
#
# 2,27,23,29,32,27,27,49,46,70
#
# 3,33,30,31,38,29,24,55,52,78
#
# 4,29,25,29,31,22,27,48,46,69
#
# 5,31,28,31,38,25,27,54,50,76
#
# 6,24,21,25,34,28,20,45,42,65
#
# 7,25,24,26,33,29,27,49,46,69
#
# 8,25,22,26,28,23,24,44,41,63
#
# 9,34,30,29,38,27,24,54,51,77
#
# 10,30,27,27,28,26,21,47,44,68
#
# 11,22,21,26,27,25,24,43,40,62
#
# 12,26,24,28,29,23,25,46,43,66
#
# 13,32,28,29,36,24,23,51,48,73
#
# 14,22,18,24,31,26,23,43,40,61
#
# 15,31,28,26,27,28,27,50,46,71
#
# 16,26,22,29,35,29,22,48,46,69
#
# 17,30,26,24,28,27,21,46,44,66
#
# 18,26,23,23,33,25,23,45,43,65
#
# 19,20,17,21,31,26,23,41,38,59
#
# 20,28,25,27,31,24,24,47,44,68
#
# 21,27,24,24,25,28,21,44,42,63
#
# 22,25,21,25,26,24,25,43,41,62
#
# 23,25,24,26,28,21,25,44,42,63
#
# 0,29,28,30,40,27,25,53,50,76
#
# 1,29,26,28,31,27,20,48,45,68
#
# 2,34,32,27,34,28,21,52,49,75
#
# 3,33,32,27,34,28,24,53,50,75
#
# 4,32,30,31,39,29,26,56,52,79
#
# 5,33,30,26,33,28,21,51,48,72
#
# 6,34,31,28,29,24,20,49,46,71
#
# 7,26,25,31,33,29,23,50,46,71
#
# 8,27,25,32,42,26,22,52,48,74
#
# 9,26,23,28,32,24,25,47,44,67
#
# 10,32,31,28,30,27,21,50,47,72
#
# 11,28,24,29,36,25,22,49,46,69
#
# 12,31,29,30,30,28,21,50,47,72
#
# 13,22,19,28,36,30,21,46,44,66
#
# 14,23,21,25,31,26,21,44,41,62
#
# 15,26,23,27,32,27,28,48,46,69
#
# 16,30,26,28,37,23,27,51,48,72
#
# 17,30,25,23,33,26,27,49,46,69
#
# 18,19,18,24,27,28,21,41,38,58
#
# 19,25,24,28,35,23,22,47,44,66
#
# 20,25,21,25,28,27,20,43,41,62
#
# 21,28,27,26,26,28,27,48,45,69
#
# 22,26,24,23,26,28,20,44,41,62
#
# 23,27,26,21,22,23,21,42,39,59
#
# 0,35,32,27,37,26,24,54,50,77
#
# 1,29,27,28,28,22,24,47,44,67
#
# 2,31,27,26,30,28,27,50,47,72
#
# 3,32,30,27,36,27,21,51,48,74
#
# 4,27,23,29,32,24,27,48,45,69
#
# 5,33,29,28,32,27,27,52,49,75
#
# 6,30,26,32,37,30,22,53,49,75
#
# 7,32,28,26,30,24,24,49,46,69
#
# 8,27,22,26,31,30,24,48,44,68
#
# 9,28,25,30,31,28,25,50,46,71
#
# 10,34,33,26,27,24,26,51,47,72
#
# 11,27,23,31,36,30,23,51,47,72
#
# 12,27,24,26,27,23,21,44,41,63
#
# 13,24,21,28,30,24,23,45,42,63
#
# 14,30,27,29,30,23,22,48,45,68
#
# 15,30,26,27,34,29,26,51,48,73
#
# 16,29,26,29,35,26,22,50,46,71
#
# 17,30,26,26,36,26,26,51,47,72
#
# 18,18,15,27,36,26,27,44,42,63
#
# 19,20,19,21,30,22,27,41,39,59
#
# 20,24,22,21,24,21,22,40,37,57
#
# 21,20,15,22,22,23,24,37,35,54
#
# 22,26,23,22,26,28,21,43,41,62
#
# 23,22,19,21,22,24,28,40,38,58
#
# 0,30,28,27,34,27,23,50,47,72
#
# 1,27,25,31,33,27,25,50,47,71
#
# 2,34,30,27,35,25,20,51,48,72
#
# 3,35,33,25,29,23,20,49,46,70
#
# 4,29,27,28,35,24,26,50,47,72
#
# 5,27,25,29,33,27,21,48,45,69
#
# 6,25,22,30,32,26,25,48,44,68
#
# 7,33,30,27,33,28,24,52,49,74
#
# 8,28,27,27,29,26,24,48,45,68
#
# 9,29,25,26,36,26,26,50,47,71
#
# 10,33,32,26,33,29,22,52,49,74
#
# 11,30,26,30,32,24,22,49,46,69
#
# 12,21,17,31,35,26,26,46,44,66
#
# 13,21,17,29,34,23,22,43,41,62
#
# 14,30,29,24,24,23,21,45,42,64
#
# 15,29,24,24,30,24,24,46,43,66
#
# 16,27,25,24,28,27,22,45,43,65
#
# 17,26,25,23,24,23,23,43,40,61
#
# 18,26,22,26,29,25,27,46,43,66
#
# 19,19,18,23,32,22,21,40,38,57
#
# 20,21,20,28,29,23,21,42,40,60
#
# 21,26,25,23,28,26,28,46,44,66
#
# 22,25,21,26,33,25,23,45,43,65
#
# 23,18,15,21,27,27,27,40,38,57
#
# 0,26,21,28,32,21,24,45,42,65
#
# 1,33,32,31,32,22,26,52,49,75
#
# 2,27,24,25,34,23,21,46,43,65
#
# 3,26,24,31,35,24,24,49,46,69
#
# 4,32,31,29,34,24,23,51,48,74
#
# 5,32,28,29,29,24,21,48,46,69
#
# 6,35,34,25,25,23,24,49,46,71
#
# 7,29,26,32,39,24,22,51,48,73
#
# 8,24,19,26,33,25,21,44,41,63
#
# 9,28,25,29,33,23,23,48,45,68
#
# 10,27,26,32,32,25,23,49,46,70
#
# 11,25,21,30,38,23,22,47,44,68
#
# 12,26,22,31,40,29,22,51,47,72
#
# 13,24,23,30,36,26,24,48,46,69
#
# 14,22,18,31,40,25,21,47,44,66
#
# 15,22,21,27,34,22,21,44,41,62
#
# 16,23,21,28,28,28,27,46,43,66
#
# 17,22,21,23,29,25,26,43,41,62
#
# 18,23,20,27,35,23,23,45,42,64
#
# 19,19,14,28,37,26,21,43,40,62
#
# 20,28,27,25,30,21,26,47,44,66
#
# 21,27,26,27,37,27,21,49,46,70
#
# 22,18,17,23,26,28,27,41,39,59
#
# 23,24,23,22,27,20,24,42,39,59
#
# 0,35,31,30,33,23,21,51,48,74
#
# 1,31,29,32,36,28,27,54,51,78
#
# 2,33,32,24,32,26,23,51,47,72
#
# 3,23,21,27,38,29,26,49,46,69
#
# 4,30,25,31,38,24,20,50,47,71
#
# 5,25,24,25,33,30,26,48,46,69
#
# 6,30,27,31,33,29,24,52,48,74
#
# 7,35,30,30,31,22,25,51,48,74
#
# 8,31,27,28,34,23,21,49,46,69
#
# 9,30,28,32,33,29,21,51,48,74
#
# 10,24,22,26,29,26,26,45,43,65
#
# 11,24,20,25,34,26,26,46,43,66
#
# 12,24,22,25,30,27,28,46,44,66
#
# 13,32,31,25,32,24,22,49,46,71
#
# 14,23,18,25,26,28,23,42,40,61
#
# 15,29,28,24,25,28,23,47,44,66
#
# 16,26,24,28,35,26,28,50,46,71
#
# 17,31,30,26,35,29,27,53,50,75
#
# 18,26,25,24,24,24,28,45,42,64
#
# 19,22,19,22,33,26,22,43,40,61
#
# 20,28,25,24,31,25,28,48,45,68
#
# 21,30,25,26,34,29,26,51,47,72
#
# 22,21,16,27,35,23,26,44,41,63
#
# 23,19,17,23,34,26,28,44,41,62
#
# 0,28,27,30,38,22,20,49,46,70
#
# 1,27,23,27,29,28,20,46,43,65
#
# 2,25,24,27,29,22,28,46,43,66
#
# 3,26,21,27,35,29,25,48,46,69
#
# 4,32,29,31,39,24,26,54,50,77
#
# 5,25,23,28,32,28,28,49,46,69
#
# 6,26,24,25,27,25,25,45,42,65
#
# 7,30,25,25,29,23,28,48,44,68
#
# 8,28,25,27,34,29,25,50,47,71
#
# 9,28,27,27,30,24,25,48,45,68
#
# 10,33,32,27,34,29,28,54,51,78
#
# 11,23,22,32,33,24,22,46,44,66
#
# 12,25,21,29,33,26,28,48,45,69
#
# 13,22,20,30,39,25,28,49,46,69
#
# 14,21,16,26,35,26,26,45,42,63
#
# 15,22,17,27,35,25,24,45,42,63
#
# 16,20,15,25,27,26,28,42,39,60
#
# 17,31,27,24,33,24,21,48,44,68
#
# 18,26,22,24,34,25,28,47,44,68
#
# 19,26,24,26,32,22,26,46,44,66
#
# 20,27,25,28,37,26,21,49,46,69
#
# 21,19,15,24,29,24,23,40,37,57
#
# 22,20,17,21,23,27,25,39,37,57
#
# 23,26,25,21,28,26,22,44,41,63
#
# 0,27,24,25,36,24,21,47,44,66
#
# 1,33,28,28,31,24,22,49,46,71
#
# 2,36,32,24,34,25,23,52,48,74
#
# 3,26,21,28,38,26,24,48,46,69
#
# 4,24,22,28,33,27,22,46,44,66
#
# 5,27,25,32,32,22,25,48,46,69
#
# 6,24,22,25,28,26,21,43,41,62
#
# 7,33,30,25,30,26,28,51,48,73
#
# 8,24,21,25,36,23,24,45,43,65
#
# 9,28,26,28,29,30,25,49,46,71
#
# 10,25,20,28,34,23,27,47,44,66
#
# 11,25,20,29,37,24,21,46,44,66
#
# 12,32,31,25,32,31,24,52,49,74
#
# 13,29,24,29,31,23,24,48,44,68
#
# 14,28,25,25,35,23,23,47,44,68
#
# 15,25,20,25,32,30,25,47,44,66
#
# 16,26,23,27,37,23,21,47,44,66
#
# 17,25,24,28,35,28,24,49,46,69
#
# 18,28,27,24,25,29,29,48,45,69
#
# 19,22,20,29,32,27,21,45,42,64
#
# 20,30,28,25,25,24,22,46,43,65
#
# 21,29,25,25,28,25,23,46,43,66
#
# 22,23,20,25,32,23,25,44,41,63
#
# 23,18,13,20,25,22,22,36,33,51
#
# 0,31,30,29,34,27,20,51,48,72
#
# 1,33,29,25,27,27,26,50,46,71
#
# 2,29,24,26,34,26,25,49,46,69
#
# 3,34,32,31,40,23,20,54,50,76
#
# 4,35,30,26,33,26,28,53,50,75
#
# 5,31,28,31,36,26,25,53,49,75
#
# 6,30,26,28,35,28,21,50,47,71
#
# 7,30,29,32,42,28,22,54,51,78
#
# 8,24,22,26,26,29,23,45,42,63
#
# 9,23,18,27,33,27,23,45,42,64
#
# 10,34,33,33,39,26,23,56,52,80
#
# 11,29,25,27,31,29,22,48,46,69
#
# 12,31,28,25,30,24,23,48,45,68
#
# 13,31,28,30,35,29,22,52,49,74
#
# 14,26,25,26,37,24,22,48,44,68
#
# 15,26,23,30,38,29,25,51,48,72
#
# 16,26,21,27,36,28,25,48,46,69
#
# 17,30,25,29,39,27,23,51,48,74
#
# 18,19,15,22,27,23,29,40,38,57
#
# 19,20,16,24,33,29,27,44,42,63
#
# 20,19,17,25,28,26,21,40,38,58
#
# 21,18,13,21,23,24,27,37,35,54
#
# 22,29,27,25,25,21,28,46,43,66
#
# 23,30,26,23,23,25,25,45,42,65
#
# 0,26,21,26,27,30,26,46,44,66
#
# 1,26,25,29,36,29,24,50,47,72
#
# 2,32,28,25,32,29,26,51,48,73
#
# 3,27,25,29,30,23,22,46,44,66
#
# 4,31,30,31,41,31,28,57,54,81
#
# 5,29,25,32,35,25,21,50,46,71
#
# 6,34,33,33,45,25,21,57,53,81
#
# 7,31,27,26,26,29,27,49,46,71
#
# 8,34,29,32,33,25,25,53,50,75
#
# 9,25,21,26,33,23,24,45,42,65
#
# 10,27,26,32,35,28,27,52,49,74
#
# 11,32,27,29,39,30,21,53,50,75
#
# 12,26,21,27,29,31,27,48,45,68
#
# 13,21,16,24,34,28,25,44,41,63
#
# 14,29,26,30,40,26,23,52,48,74
#
# 15,28,24,28,34,29,28,51,48,72
#
# 16,23,22,28,35,29,23,48,44,68
#
# 17,25,20,23,30,25,21,43,40,61
#
# 18,21,17,24,29,23,28,42,40,60
#
# 19,30,25,25,36,29,28,51,48,74
#
# 20,28,24,23,25,27,21,44,41,63
#
# 21,18,14,24,33,23,22,40,37,57
#
# 22,24,21,20,20,22,24,39,36,56
#
# 23,21,18,26,26,26,27,43,40,61
#
# 0,35,31,24,34,25,21,51,47,72
#
# 1,34,33,25,30,30,22,52,48,74
#
# 2,28,25,25,36,28,22,49,46,69
#
# 3,30,25,26,36,30,23,51,47,72
#
# 4,24,20,27,29,25,26,45,42,64
#
# 5,36,31,27,29,30,27,54,50,76
#
# 6,35,33,33,35,22,27,55,52,78
#
# 7,32,26,33,40,23,22,52,49,75
#
# 8,26,25,28,38,27,25,50,47,72
#
# 9,31,25,32,36,29,29,54,51,77
#
# 10,23,19,25,27,30,28,45,42,65
#
# 11,23,18,27,33,25,28,46,43,65
#
# 12,29,24,29,33,27,24,49,46,71
#
# 13,27,23,26,35,26,25,48,45,69
#
# 14,32,30,31,42,23,22,54,50,76
#
# 15,28,22,28,31,29,26,49,46,69
#
# 16,21,17,24,28,30,27,44,41,62
#
# 17,27,23,22,30,27,29,47,44,67
#
# 18,20,15,28,35,24,28,45,42,63
#
# 19,25,22,28,33,23,26,47,44,66
#
# 20,23,21,26,29,22,27,44,41,63
#
# 21,23,22,26,29,24,28,45,42,65
#
# 22,27,22,26,31,23,23,45,42,65
#
# 23,25,21,20,24,27,26,42,40,61
#
# 0,29,26,25,28,26,28,48,45,69
#
# 1,33,31,25,37,25,27,53,50,75
#
# 2,24,23,29,32,28,28,49,46,69
#
# 3,34,29,29,39,26,25,54,51,77
#
# 4,25,20,28,35,23,25,46,44,66
#
# 5,29,25,30,40,27,23,52,48,74
#
# 6,28,27,28,31,27,26,50,46,71
#
# 7,23,20,26,35,28,27,47,44,68
#
# 8,33,30,27,29,29,25,51,48,74
#
# 9,36,35,26,31,28,27,54,51,78
#
# 10,26,21,29,39,28,27,51,47,72
#
# 11,21,20,26,27,27,24,43,40,62
#
# 12,23,21,24,27,30,28,45,43,65
#
# 13,31,28,24,35,23,26,50,46,71
#
# 14,20,19,24,29,30,25,44,41,62
#
# 15,32,29,26,36,23,23,50,47,72
#
# 16,27,25,24,29,28,23,46,44,66
#
# 17,22,20,23,31,22,26,43,40,61
#
# 18,24,20,28,28,25,26,45,42,64
#
# 19,31,29,28,32,26,21,50,46,71
#
# 20,30,25,26,32,25,23,48,45,68
#
# 21,22,21,20,27,25,23,41,38,59
#
# 22,18,17,21,28,29,22,40,38,57
#
# 23,28,24,21,33,22,27,46,43,66
#
# 0,24,22,26,28,23,28,45,42,64
#
# 1,24,19,32,37,24,24,48,44,68
#
# 2,34,33,33,38,22,22,54,51,77
#
# 3,24,20,29,29,27,24,45,43,65
#
# 4,25,23,26,31,31,24,48,44,68
#
# 5,28,23,28,29,31,26,49,46,70
#
# 6,33,31,26,34,25,28,53,49,75
#
# 7,37,34,28,33,28,26,55,52,79
#
# 8,26,20,27,38,23,21,46,43,66
#
# 9,28,23,25,31,31,26,49,46,69
#
# 10,31,28,26,30,27,28,51,47,72
#
# 11,33,31,26,32,31,26,53,50,76
#
# 12,29,28,24,28,30,30,50,47,72
#
# 13,29,26,24,27,30,23,47,44,68
#
# 14,31,26,32,42,30,29,57,53,80
#
# 15,24,19,28,35,30,24,48,44,68
#
# 16,22,20,23,24,24,29,42,40,60
#
# 17,21,20,24,36,23,25,44,42,63
#
# 18,32,31,27,39,24,22,52,49,74
#
# 19,26,25,21,28,22,22,43,40,61
#
# 20,30,25,23,27,26,26,47,44,66
#
# 21,20,16,27,35,27,22,44,41,62
#
# 22,25,24,22,31,24,24,45,42,63
#
# 23,22,19,19,20,21,21,36,34,52
#
# 0,37,33,32,39,22,24,56,52,79
#
# 1,36,34,31,42,24,26,57,54,82
#
# 2,28,24,30,38,26,21,50,46,71
#
# 3,28,23,28,28,30,29,49,46,71
#
# 4,31,29,27,34,23,22,49,46,71
#
# 5,26,25,30,35,27,28,51,48,72
#
# 6,30,25,32,44,29,23,54,51,78
#
# 7,38,37,31,35,30,23,58,54,82
#
# 8,29,27,32,43,24,25,54,50,76
#
# 9,26,20,29,32,28,25,48,44,68
#
# 10,35,30,24,32,24,22,50,46,71
#
# 11,34,33,28,33,31,26,55,52,78
#
# 12,25,23,28,29,28,21,46,43,65
#
# 13,32,31,26,29,30,28,52,49,75
#
# 14,28,23,28,41,26,27,51,48,74
#
# 15,26,24,29,29,31,26,49,46,70
#
# 16,29,24,26,37,26,24,49,46,71
#
# 17,23,20,22,26,23,22,40,38,58
#
# 18,31,30,26,33,28,29,53,49,75
#
# 19,31,26,26,33,24,28,50,47,71
#
# 20,28,23,30,35,28,24,50,47,71
#
# 21,30,29,25,34,27,27,51,48,73
#
# 22,24,20,22,32,29,21,44,41,63
#
# 23,18,13,24,28,28,27,41,38,59
#
# 0,34,28,31,34,21,27,52,49,74
#
# 1,35,32,32,45,23,27,58,54,82
#
# 2,34,29,30,38,28,28,56,52,79
#
# 3,25,24,31,36,24,20,48,44,68
#
# 4,38,36,29,35,27,25,57,53,80
#
# 5,25,20,30,39,24,20,47,44,67
#
# 6,35,31,32,43,23,30,58,54,82
#
# 7,25,24,29,32,29,26,49,46,70
#
# 8,37,33,33,44,31,28,61,58,87
#
# 9,24,22,30,30,25,27,47,44,67
#
# 10,25,23,28,34,28,29,50,46,71
#
# 11,31,30,30,32,25,25,51,48,74
#
# 12,30,28,26,32,26,22,49,46,69
#
# 13,24,23,24,25,29,24,44,42,63
#
# 14,34,30,23,29,32,22,51,47,72
#
# 15,34,32,26,38,25,23,53,50,75
#
# 16,25,22,28,31,22,28,46,44,66
#
# 17,30,26,28,32,30,29,52,49,74
#
# 18,26,24,28,38,23,25,49,46,69
#
# 19,23,22,24,26,25,28,44,41,63
#
# 20,21,19,26,29,30,23,44,41,63
#
# 21,28,23,29,36,25,25,49,46,71
#
# 22,29,28,20,28,24,22,45,42,64
#
# 23,31,29,21,31,24,29,49,46,70
#
# 0,34,31,33,34,21,24,53,49,75
#
# 1,28,23,31,37,28,27,52,48,74
#
# 2,24,18,33,46,22,27,51,47,72
#
# 3,38,36,26,33,24,26,54,51,78
#
# 4,28,27,34,45,27,21,54,51,77
#
# 5,27,26,32,42,31,27,55,52,78
#
# 6,35,32,27,36,24,28,54,51,77
#
# 7,31,30,30,31,30,24,52,49,75
#
# 8,36,32,26,37,29,28,56,52,80
#
# 9,29,27,33,42,24,28,54,51,78
#
# 10,29,24,24,25,23,21,43,41,62
#
# 11,30,28,28,40,28,26,54,50,76
#
# 12,27,25,25,34,25,22,47,44,67
#
# 13,22,19,31,41,25,22,48,44,68
#
# 14,33,30,25,31,31,23,51,48,74
#
# 15,25,19,27,37,28,30,49,46,71
#
# 16,21,16,26,26,31,29,44,42,63
#
# 17,33,30,22,25,23,29,48,45,69
#
# 18,19,13,26,28,24,24,40,37,57
#
# 19,21,15,28,40,29,27,48,44,68
#
# 20,29,25,29,38,27,29,53,49,75
#
# 21,22,19,26,31,27,28,45,43,65
#
# 22,17,13,25,26,27,25,39,37,57
#
# 23,29,28,21,30,27,26,48,45,68
#
# 0,25,20,25,27,27,22,43,41,62
#
# 1,32,31,26,29,28,25,51,48,72
#
# 2,33,31,27,36,28,20,52,49,74
#
# 3,34,33,33,44,30,28,60,56,86
#
# 4,26,20,32,41,26,23,50,47,71
#
# 5,33,28,29,36,30,21,53,49,75
#
# 6,32,29,33,34,26,26,54,50,76
#
# 7,36,33,28,39,30,22,56,52,80
#
# 8,25,20,33,33,31,22,49,46,69
#
# 9,30,28,34,37,29,26,55,51,78
#
# 10,32,31,32,34,30,22,54,50,77
#
# 11,29,26,30,31,32,23,51,48,72
#
# 12,28,25,30,37,23,22,49,46,70
#
# 13,30,27,32,32,24,27,51,48,73
#
# 14,30,25,30,38,32,30,55,52,78
#
# 15,24,19,23,32,30,23,45,42,64
#
# 16,24,21,26,33,26,29,47,44,68
#
# 17,24,18,24,31,28,25,45,42,63
#
# 18,28,27,31,38,24,27,52,49,74
#
# 19,32,29,21,28,30,23,48,46,69
#
# 20,30,28,23,23,27,27,47,44,67
#
# 21,24,20,22,31,28,27,45,42,65
#
# 22,31,28,21,28,28,23,47,44,68
#
# 23,31,26,27,31,28,22,49,46,70
#
# 0,36,31,26,32,29,20,52,48,74
#
# 1,28,22,28,33,24,28,48,46,69
#
# 2,28,26,29,33,29,20,49,46,70
#
# 3,32,27,32,33,23,29,52,49,75
#
# 4,33,27,33,33,30,21,53,49,75
#
# 5,37,32,32,35,27,29,57,54,81
#
# 6,27,25,31,31,32,25,51,48,72
#
# 7,25,19,26,33,30,24,47,44,66
#
# 8,31,25,25,33,24,27,49,46,70
#
# 9,36,30,32,32,27,27,55,51,78
#
# 10,23,17,28,31,32,29,48,44,68
#
# 11,24,18,26,33,23,22,43,41,62
#
# 12,30,29,31,35,23,24,51,48,73
#
# 13,29,28,30,31,32,21,51,48,72
#
# 14,33,27,31,42,28,25,55,52,79
#
# 15,34,31,27,36,28,25,54,50,77
#
# 16,30,29,29,31,29,30,53,50,75
#
# 17,19,16,23,35,25,21,41,39,59
#
# 18,19,16,28,30,26,28,44,41,62
#
# 19,24,18,30,33,27,23,46,43,66
#
# 20,29,23,29,42,27,25,52,49,74
#
# 21,18,17,20,28,25,28,40,38,58
#
# 22,19,15,24,24,26,26,40,37,57
#
# 23,23,21,26,36,24,25,46,43,66
#
# 0,26,22,26,30,23,27,46,43,65
#
# 1,38,35,27,28,26,26,54,50,76
#
# 2,30,29,26,26,30,26,50,46,71
#
# 3,32,31,31,44,26,29,57,54,82
#
# 4,35,34,29,40,28,26,57,54,81
#
# 5,25,22,28,31,28,23,47,44,66
#
# 6,29,26,32,36,22,23,50,47,71
#
# 7,28,22,25,25,31,20,45,42,64
#
# 8,38,36,31,43,26,27,60,56,85
#
# 9,34,32,34,45,30,29,61,57,86
#
# 10,24,21,25,31,31,29,48,45,68
#
# 11,35,34,31,41,29,21,57,53,81
#
# 12,28,22,27,29,31,23,48,44,68
#
# 13,31,30,31,42,23,21,53,50,75
#
# 14,32,28,26,38,25,22,51,48,72
#
# 15,26,25,31,38,28,29,53,49,75
#
# 16,30,28,28,28,26,24,49,46,69
#
# 17,25,19,31,31,27,25,47,44,67
#
# 18,27,21,22,31,23,28,45,42,65
#
# 19,21,15,28,37,29,26,46,44,66
#
# 20,29,26,20,26,28,30,47,44,68
#
# 21,30,27,26,30,23,23,47,44,68
#
# 22,22,21,27,38,27,22,47,44,66
#
# 23,24,21,20,26,26,23,42,39,59
#
# 0,28,25,28,28,23,29,48,45,68
#
# 1,31,28,30,36,24,23,51,48,73
#
# 2,27,25,28,33,24,26,48,46,69
#
# 3,29,25,32,35,31,25,53,49,75
#
# 4,37,36,34,38,22,23,57,53,80
#
# 5,38,33,25,30,31,21,53,50,75
#
# 6,35,33,29,29,30,25,54,50,77
#
# 7,30,28,29,32,32,21,51,48,73
#
# 8,24,20,33,41,25,27,51,47,72
#
# 9,33,31,32,36,25,27,55,51,78
#
# 10,27,25,34,35,31,23,52,49,74
#
# 11,31,29,24,26,31,29,51,47,72
#
# 12,23,19,32,42,26,30,51,48,73
#
# 13,22,20,24,28,29,27,45,42,63
#
# 14,34,33,24,33,29,24,53,49,75
#
# 15,35,30,31,32,32,23,54,51,78
#
# 16,26,25,23,29,31,29,48,46,69
#
# 17,35,32,27,36,31,28,56,53,80
#
# 18,21,20,26,36,29,25,47,44,66
#
# 19,24,17,22,27,24,24,41,38,59
#
# 20,21,17,29,38,31,27,48,46,69
#
# 21,30,27,30,32,28,23,51,47,72
#
# 22,25,21,25,36,24,28,47,44,68
#
# 23,25,23,20,23,24,27,42,40,60
#
# 0,36,29,30,36,22,24,53,49,75
#
# 1,24,18,31,41,25,29,50,47,71
#
# 2,35,34,26,34,29,28,55,52,79
#
# 3,37,36,30,40,25,26,58,54,82
#
# 4,38,33,26,26,32,26,54,50,77
#
# 5,33,27,33,37,23,28,54,50,77
#
# 6,34,29,25,38,23,27,52,49,75
#
# 7,25,24,30,43,32,21,52,49,74
#
# 8,26,25,30,36,23,26,49,46,71
#
# 9,38,35,25,30,23,28,53,50,76
#
# 10,27,24,27,36,32,26,51,48,73
#
# 11,31,26,24,26,32,30,50,47,72
#
# 12,27,26,30,30,31,28,51,48,73
#
# 13,23,22,29,31,29,21,46,43,66
#
# 14,32,30,27,40,25,21,52,49,74
#
# 15,26,25,25,29,31,29,49,46,70
#
# 16,30,27,27,39,24,30,53,49,75
#
# 17,24,20,22,35,24,22,44,41,62
#
# 18,31,29,31,43,24,22,54,50,76
#
# 19,21,18,22,23,31,27,42,40,60
#
# 20,27,25,23,32,27,31,49,46,70
#
# 21,26,23,28,32,25,30,49,46,69
#
# 22,25,23,29,31,22,28,47,44,67
#
# 23,32,29,22,25,24,25,47,44,66
#
# 0,35,33,24,27,24,30,51,48,74
#
# 1,37,35,26,30,28,26,54,51,77
#
# 2,24,18,33,37,31,25,50,47,71
#
# 3,38,36,32,39,32,27,61,57,86
#
# 4,27,23,26,33,25,25,47,44,68
#
# 5,27,22,31,37,23,22,48,45,69
#
# 6,32,27,31,42,30,30,57,54,81
#
# 7,38,37,26,30,28,26,55,52,78
#
# 8,23,22,31,36,30,30,51,48,73
#
# 9,32,29,25,33,33,24,52,49,75
#
# 10,32,31,32,41,30,28,58,54,82
#
# 11,32,29,28,32,24,29,52,48,74
#
# 12,21,20,29,37,23,30,48,44,68
#
# 13,26,24,27,36,29,24,49,46,71
#
# 14,35,29,30,36,24,21,52,49,74
#
# 15,33,29,31,31,29,27,54,50,76
#
# 16,21,19,24,37,31,27,47,44,68
#
# 17,27,21,27,32,25,31,48,46,69
#
# 18,22,21,30,38,24,26,48,45,68
#
# 19,32,26,23,33,27,27,50,47,71
#
# 20,21,16,28,39,30,25,47,44,68
#
# 21,27,26,20,30,22,27,45,42,65
#
# 22,21,17,21,29,28,21,41,38,58
#
# 23,18,17,23,31,24,31,43,40,61
#
# 0,40,38,28,33,28,23,57,53,80
#
# 1,37,31,34,36,22,27,56,52,79
#
# 2,28,26,32,38,25,29,53,50,75
#
# 3,36,32,29,33,31,27,56,52,80
#
# 4,25,22,29,36,24,23,47,44,68
#
# 5,29,23,25,35,26,29,50,46,71
#
# 6,37,30,25,30,24,27,51,48,74
#
# 7,23,22,30,37,24,28,49,46,69
#
# 8,34,31,26,39,23,27,54,50,76
#
# 9,22,17,33,42,33,26,51,48,74
#
# 10,38,36,30,34,25,30,57,54,82
#
# 11,33,32,24,37,29,26,54,50,77
#
# 12,38,31,34,39,29,21,57,54,81
#
# 13,23,22,32,40,26,22,49,46,70
#
# 14,26,20,28,38,23,21,46,44,66
#
# 15,32,26,28,41,30,28,55,52,78
#
# 16,22,21,25,30,25,23,43,41,62
#
# 17,28,25,30,42,24,26,52,49,74
#
# 18,33,30,22,28,24,31,50,47,71
#
# 19,21,17,31,36,23,25,45,43,65
#
# 20,30,29,21,26,22,24,45,42,65
#
# 21,32,27,27,29,23,24,48,45,69
#
# 22,31,27,25,36,28,29,52,49,75
#
# 23,28,23,25,39,27,28,51,47,72
#
# 0,38,33,26,26,22,21,49,46,71
#
# 1,36,35,26,31,21,27,52,49,75
#
# 2,40,37,28,30,26,23,55,51,78
#
# 3,39,37,28,38,32,27,60,56,85
#
# 4,25,24,29,33,23,31,49,46,70
#
# 5,38,32,34,49,29,22,61,57,86
#
# 6,28,22,34,36,33,28,54,50,77
#
# 7,26,25,35,37,23,25,51,48,72
#
# 8,25,22,30,33,29,30,50,47,72
#
# 9,32,26,34,45,25,29,57,53,81
#
# 10,22,18,30,36,27,29,48,45,69
#
# 11,29,23,24,26,23,26,45,42,64
#
# 12,27,23,28,40,24,28,51,47,72
#
# 13,27,23,26,35,30,27,50,47,71
#
# 14,34,33,31,37,33,27,58,54,83
#
# 15,33,26,32,44,26,26,56,52,79
#
# 16,25,19,31,44,26,31,52,49,75
#
# 17,26,21,23,33,25,30,47,44,67
#
# 18,25,19,30,44,24,27,50,47,72
#
# 19,25,24,25,31,27,21,45,43,65
#
# 20,21,19,25,25,32,26,44,41,63
#
# 21,26,24,23,38,27,21,47,44,68
#
# 22,31,30,23,32,21,26,48,46,69
#
# 23,29,27,26,36,29,26,51,48,74
#
# 0,34,27,33,42,23,27,55,52,79
#
# 1,25,24,24,27,26,31,47,44,66
#
# 2,37,32,29,42,30,28,59,55,84
#
# 3,28,23,27,42,33,30,54,51,78
#
# 4,40,37,33,41,23,21,58,54,83
#
# 5,33,31,31,35,30,24,55,51,78
#
# 6,27,26,31,43,32,30,56,53,80
#
# 7,40,34,24,24,23,31,52,49,75
#
# 8,23,18,35,39,27,22,49,46,69
#
# 9,31,27,30,41,27,21,53,49,75
#
# 10,24,20,27,30,26,22,44,42,63
#
# 11,26,21,30,37,29,26,50,47,72
#
# 12,25,21,33,39,28,23,50,47,72
#
# 13,28,26,32,44,31,25,55,52,79
#
# 14,37,31,24,36,28,30,55,52,79
#
# 15,24,22,30,42,29,27,52,48,74
#
# 16,27,21,25,35,23,24,46,43,66
#
# 17,35,29,22,22,23,22,45,43,65
#
# 18,31,28,28,40,25,22,52,48,74
#
# 19,20,16,25,28,26,22,41,38,58
#
# 20,29,23,20,25,25,28,45,42,63
#
# 21,33,26,24,37,31,25,52,49,75
#
# 22,30,25,23,36,27,26,50,46,71
#
# 23,30,29,25,40,28,24,52,49,75
#
# 0,38,32,28,40,32,24,58,54,82
#
# 1,39,38,34,46,25,27,62,58,89
#
# 2,25,23,29,42,32,25,52,49,75
#
# 3,26,25,33,39,23,29,52,49,74
#
# 4,36,34,28,35,26,31,57,53,80
#
# 5,32,25,32,32,24,26,51,48,72
#
# 6,32,29,33,34,24,28,54,50,76
#
# 7,25,21,31,43,30,27,53,49,75
#
# 8,36,32,33,38,32,23,58,54,82
#
# 9,36,32,33,43,30,24,59,55,84
#
# 10,34,30,25,39,24,22,52,48,74
#
# 11,28,24,26,36,24,27,49,46,70
#
# 12,31,28,27,36,23,21,49,46,71
#
# 13,31,27,29,44,23,32,55,52,79
#
# 14,37,34,27,29,26,22,52,49,74
#
# 15,20,14,33,39,32,25,48,46,69
#
# 16,22,17,25,38,28,21,45,42,64
#
# 17,27,24,28,31,22,25,47,44,66
#
# 18,21,17,25,36,30,21,45,42,63
#
# 19,33,29,31,40,23,25,54,50,77
#
# 20,28,22,24,38,22,23,47,44,66
#
# 21,34,32,24,35,25,31,54,50,77
#
# 22,28,21,19,24,25,27,43,40,61
#
# 23,32,31,29,44,21,27,55,51,78
#
# 0,31,29,34,37,28,22,54,50,77
#
# 1,29,24,25,29,28,24,47,44,68
#
# 2,37,35,30,45,32,30,62,58,89
#
# 3,27,24,34,40,25,27,53,49,75
#
# 4,26,25,32,44,25,23,52,49,74
#
# 5,31,29,31,35,31,29,55,52,79
#
# 6,34,27,26,34,23,27,51,48,72
#
# 7,30,28,32,47,25,28,57,53,80
#
# 8,27,22,27,32,26,26,48,44,68
#
# 9,27,26,34,40,25,24,52,49,75
#
# 10,34,30,24,37,24,21,51,47,72
#
# 11,27,22,29,35,34,24,51,48,72
#
# 12,25,24,27,41,30,24,51,48,72
#
# 13,31,28,33,33,31,31,56,52,79
#
# 14,32,27,30,45,26,21,54,50,77
#
# 15,20,15,24,25,31,27,42,40,60
#
# 16,26,25,30,41,29,29,54,50,76
#
# 17,32,27,24,36,27,23,50,47,72
#
# 18,32,31,32,40,27,27,56,53,80
#
# 19,26,25,30,36,29,30,52,49,75
#
# 20,19,17,25,32,24,21,41,38,59
#
# 21,33,28,29,34,32,29,55,52,78
#
# 22,33,29,24,25,29,21,48,45,68
#
# 23,22,21,30,34,21,31,47,44,68
#
# 0,27,23,32,45,25,31,54,51,78
#
# 1,34,27,26,26,31,24,50,47,71
#
# 2,36,31,32,46,31,31,62,58,87
#
# 3,26,24,25,37,22,24,47,44,67
#
# 4,24,19,33,34,30,25,49,46,70
#
# 5,36,35,34,36,30,20,57,53,81
#
# 6,41,40,25,33,28,24,57,53,81
#
# 7,31,24,29,43,33,31,57,53,81
#
# 8,36,31,31,38,24,30,57,53,80
#
# 9,30,23,29,41,23,29,52,49,74
#
# 10,32,26,34,47,33,22,58,54,82
#
# 11,35,29,35,36,23,21,53,50,76
#
# 12,34,33,29,40,32,29,59,55,83
#
# 13,27,26,28,42,24,28,52,49,74
#
# 14,27,23,34,48,30,23,55,52,78
#
# 15,28,23,24,38,26,30,50,47,72
#
# 16,28,26,27,37,33,31,54,51,77
#
# 17,35,28,27,40,33,31,58,54,82
#
# 18,24,18,26,37,30,21,46,44,66
#
# 19,35,31,32,45,32,24,59,56,84
#
# 20,20,14,31,34,24,30,45,43,65
#
# 21,25,21,28,43,27,31,52,49,74
#
# 22,34,28,25,26,26,23,48,45,69
#
# 23,18,15,19,29,26,22,38,36,55
#
# 0,27,22,27,35,29,21,48,45,68
#
# 1,34,33,24,37,29,31,56,52,80
#
# 2,31,29,28,30,23,25,49,46,71
#
# 3,32,30,25,35,32,27,54,50,77
#
# 4,41,37,25,27,23,30,54,51,78
#
# 5,29,22,33,47,25,25,54,50,77
#
# 6,30,29,34,43,33,25,58,54,82
#
# 7,36,29,30,33,23,27,53,50,75
#
# 8,26,19,27,31,32,28,48,46,69
#
# 9,33,27,31,47,32,26,58,55,83
#
# 10,38,32,34,40,31,22,59,55,83
#
# 11,39,32,24,26,33,28,54,51,77
#
# 12,38,35,25,33,32,31,58,54,82
#
# 13,30,24,27,28,25,26,48,44,68
#
# 14,33,26,25,28,30,32,52,48,74
#
# 15,31,26,33,40,24,31,55,52,78
#
# 16,27,26,25,38,26,23,49,46,70
#
# 17,31,27,25,40,25,31,53,50,76
#
# 18,29,25,23,32,31,32,51,48,73
#
# 19,33,31,32,43,27,31,59,55,83
#
# 20,18,16,22,33,31,25,43,40,62
#
# 21,26,20,27,38,24,24,47,44,68
#
# 22,23,21,25,25,29,30,45,43,65
#
# 23,20,14,21,31,31,22,41,39,59
#
# 0,36,32,30,46,25,24,57,54,82
#
# 1,28,21,27,41,25,20,48,45,69
#
# 2,34,29,24,33,29,25,52,48,74
#
# 3,28,25,32,43,22,21,51,48,72
#
# 4,30,28,34,46,24,28,57,53,80
#
# 5,36,35,32,48,24,21,58,55,83
#
# 6,24,22,33,44,30,22,52,49,74
#
# 7,36,35,35,43,33,25,62,58,87
#
# 8,41,37,25,31,25,30,56,53,80
#
# 9,32,26,33,47,32,24,58,54,82
#
# 10,25,19,25,31,28,20,44,41,63
#
# 11,30,27,35,40,25,28,55,52,78
#
# 12,34,28,29,33,29,29,54,51,77
#
# 13,39,33,25,39,25,21,54,51,77
#
# 14,32,29,35,49,32,22,59,56,84
#
# 15,35,34,28,30,31,24,54,51,77
#
# 16,36,35,31,42,33,26,60,57,86
#
# 17,37,36,22,29,26,30,54,50,76
#
# 18,34,33,22,35,30,26,54,50,76
#
# 19,28,26,30,33,33,23,51,48,74
#
# 20,27,26,28,36,23,28,50,47,71
#
# 21,35,33,31,41,25,30,58,54,83
#
# 22,20,12,30,40,27,27,46,44,66
#
# 23,24,17,27,31,23,31,45,43,65
#
# 0,36,33,32,46,27,29,60,57,86
#
# 1,40,38,34,50,30,31,66,62,95
#
# 2,25,24,25,40,34,29,53,49,75
#
# 3,26,18,25,34,31,23,47,44,66
#
# 4,40,39,33,35,32,25,61,57,86
#
# 5,25,22,30,34,23,25,47,44,68
#
# 6,40,38,27,29,23,23,54,50,76
#
# 7,33,26,36,48,30,22,58,54,83
#
# 8,32,31,33,49,28,32,61,57,87
#
# 9,26,25,29,34,27,28,50,47,72
#
# 10,40,38,28,31,30,29,58,55,83
#
# 11,32,30,33,48,26,29,59,55,84
#
# 12,23,15,31,35,24,27,46,43,66
#
# 13,39,33,26,41,28,29,58,55,83
#
# 14,35,32,30,30,28,25,54,50,76
#
# 15,20,13,32,44,23,28,48,44,68
#
# 16,35,29,33,45,30,33,61,57,87
#
# 17,26,23,30,44,24,29,52,49,75
#
# 18,31,24,22,27,27,24,46,43,66
#
# 19,34,32,32,40,31,32,60,56,85
#
# 20,27,24,25,30,21,32,47,44,68
#
# 21,28,27,26,30,21,28,48,44,68
#
# 22,34,28,23,32,27,26,51,47,72
#
# 23,21,16,26,35,26,26,45,42,63
#
# 0,38,33,24,27,31,27,54,50,76
#
# 1,24,19,24,40,29,25,48,45,68
#
# 2,36,30,32,46,22,25,57,53,81
#
# 3,26,20,33,48,22,24,51,48,74
#
# 4,42,38,31,35,29,21,58,55,83
#
# 5,24,18,28,32,30,20,45,42,65
#
# 6,32,30,26,31,30,30,53,50,76
#
# 7,28,25,25,25,31,25,47,44,68
#
# 8,34,30,31,33,30,24,54,51,77
#
# 9,36,30,27,36,31,32,57,54,81
#
# 10,28,21,36,48,28,26,56,52,79
#
# 11,30,28,25,36,24,23,49,46,71
#
# 12,33,31,33,46,26,27,58,55,83
#
# 13,30,23,31,41,28,22,52,49,74
#
# 14,25,19,27,41,28,25,49,46,70
#
# 15,21,17,26,30,26,28,44,41,63
#
# 16,34,31,31,31,26,21,52,48,74
#
# 17,36,32,22,38,32,23,54,51,78
#
# 18,23,17,27,38,27,27,47,44,68
#
# 19,25,22,22,28,29,31,47,44,66
#
# 20,36,30,26,41,25,23,54,50,77
#
# 21,35,28,27,38,24,33,55,52,78
#
# 22,27,20,31,35,23,30,49,46,71
#
# 23,24,16,26,26,21,32,43,40,62
#
# 0,24,16,36,49,23,22,51,47,72
#
# 1,36,32,26,28,32,28,54,51,77
#
# 2,27,26,31,39,25,24,51,48,73
#
# 3,24,17,28,31,24,25,44,42,63
#
# 4,39,33,36,53,31,31,66,62,95
#
# 5,26,24,35,47,32,26,57,53,80
#
# 6,26,22,29,34,33,27,51,48,72
#
# 7,25,21,30,41,26,29,51,48,73
#
# 8,24,19,33,44,33,25,53,50,75
#
# 9,29,27,32,46,27,28,56,53,80
#
# 10,33,29,25,35,29,29,54,50,76
#
# 11,37,31,25,35,26,22,52,49,75
#
# 12,33,32,29,30,27,29,54,50,76
#
# 13,35,30,23,34,32,24,53,50,75
#
# 14,37,32,24,39,32,26,57,53,80
#
# 15,20,15,23,32,30,23,42,40,61
#
# 16,20,18,25,36,28,31,47,44,67
#
# 17,35,30,27,28,33,22,52,49,74
#
# 18,31,26,26,40,27,27,53,49,75
#
# 19,23,21,30,33,25,30,48,45,69
#
# 20,34,32,25,36,31,26,55,51,78
#
# 21,25,23,27,37,26,28,49,46,71
#
# 22,25,21,29,30,27,32,49,46,69
#
# 23,36,31,19,33,25,21,49,46,70
#
# 0,24,20,28,29,29,30,48,44,68
#
# 1,34,29,35,43,25,31,59,55,83
#
# 2,42,40,31,42,23,27,61,57,87
#
# 3,31,25,33,36,22,21,50,47,71
#
# 4,24,21,36,49,31,32,57,54,82
#
# 5,29,25,25,26,32,25,48,45,69
#
# 6,30,24,27,30,31,21,48,46,69
#
# 7,36,35,35,43,28,26,60,57,86
#
# 8,40,36,26,28,26,23,53,50,76
#
# 9,29,23,34,45,32,22,55,52,78
#
# 10,37,31,28,43,23,29,57,53,81
#
# 11,27,21,33,49,28,32,57,53,80
#
# 12,21,18,24,40,23,30,46,44,66
#
# 13,28,24,27,38,23,30,51,47,72
#
# 14,27,23,25,31,30,30,49,46,71
#
# 15,22,14,28,41,28,27,48,44,68
#
# 16,27,20,24,30,26,31,47,44,67
#
# 17,24,17,26,39,27,31,49,46,69
#
# 18,29,25,29,40,33,30,55,52,79
#
# 19,26,23,23,30,23,30,46,43,66
#
# 20,24,21,30,39,25,28,50,46,71
#
# 21,33,26,22,39,31,23,52,48,74
#
# 22,23,18,20,21,28,32,42,40,60
#
# 23,32,26,29,32,32,22,51,48,74
#
# 0,27,22,28,38,33,23,51,48,72
#
# 1,30,29,34,41,34,27,58,54,83
#
# 2,35,31,33,35,25,31,57,53,80
#
# 3,37,35,35,35,34,25,60,56,85
#
# 4,28,27,26,40,32,25,53,50,75
#
# 5,34,32,33,43,26,24,57,54,81
#
# 6,24,23,30,40,27,23,50,46,71
#
# 7,26,21,32,47,31,26,54,51,78
#
# 8,38,30,26,38,28,28,56,52,80
#
# 9,24,23,25,27,25,26,45,42,63
#
# 10,33,26,29,45,28,23,55,51,78
#
# 11,28,20,35,43,29,22,53,49,75
#
# 12,36,28,32,41,23,30,57,53,80
#
# 13,25,24,25,42,22,25,48,46,69
#
# 14,21,15,25,25,29,29,43,40,61
#
# 15,36,33,23,37,23,33,55,52,78
#
# 16,30,24,27,27,31,27,49,46,71
#
# 17,28,25,32,38,34,24,54,50,77
#
# 18,23,16,22,30,31,25,44,41,62
#
# 19,27,25,30,32,25,25,49,46,69
#
# 20,18,15,24,28,32,21,41,38,59
#
# 21,23,22,20,24,23,31,42,40,61
#
# 22,29,22,19,33,21,22,43,41,62
#
# 23,29,25,20,27,28,29,47,44,67
#
# 0,41,38,24,28,22,23,52,49,75
#
# 1,37,32,31,31,26,25,54,51,77
#
# 2,41,39,35,41,32,28,64,60,92
#
# 3,34,26,37,54,34,20,61,57,87
#
# 4,31,23,28,31,30,30,51,48,74
#
# 5,41,34,28,43,32,25,60,57,86
#
# 6,26,21,30,39,26,25,50,46,71
#
# 7,23,16,28,30,24,21,42,40,60
#
# 8,37,33,36,48,32,30,64,60,92
#
# 9,39,36,30,39,25,23,57,54,81
#
# 10,25,17,32,43,23,31,51,48,72
#
# 11,28,27,31,36,26,22,51,47,72
#
# 12,28,24,27,43,30,21,51,48,74
#
# 13,20,18,25,34,27,33,47,44,66
#
# 14,34,27,35,44,33,29,60,56,86
#
# 15,21,20,24,41,28,31,49,46,70
#
# 16,35,32,26,29,34,21,53,49,75
#
# 17,31,28,25,35,32,30,54,50,77
#
# 18,23,20,31,43,22,23,48,45,69
#
# 19,23,22,31,42,33,21,51,48,73
#
# 20,28,21,21,28,30,32,48,44,68
#
# 21,32,24,26,38,21,26,50,46,71
#
# 22,17,15,21,23,33,23,39,37,56
#
# 23,34,31,27,41,21,27,54,50,77
#
# 0,37,34,25,28,34,25,54,51,78
#
# 1,35,29,35,48,22,31,60,56,84
#
# 2,30,24,30,47,30,26,56,52,79
#
# 3,26,20,35,47,25,28,54,50,77
#
# 4,41,33,26,39,25,31,58,54,83
#
# 5,31,25,25,32,23,23,47,44,68
#
# 6,42,39,32,45,25,25,62,58,88
#
# 7,39,37,33,33,34,28,61,57,86
#
# 8,38,31,31,44,30,23,59,55,83
#
# 9,24,18,33,46,29,32,54,51,77
#
# 10,31,27,25,34,32,33,54,51,77
#
# 11,32,30,36,49,32,23,60,56,86
#
# 12,40,33,33,42,23,29,60,56,84
#
# 13,35,34,34,38,29,32,60,56,86
#
# 14,33,32,27,39,34,30,58,54,83
#
# 15,38,36,31,43,25,27,60,56,84
#
# 16,33,26,26,33,27,33,53,50,75
#
# 17,23,20,27,39,27,29,49,46,70
#
# 18,35,28,26,33,30,21,51,48,74
#
# 19,36,28,30,42,26,26,56,52,80
#
# 20,27,24,33,36,29,32,54,50,77
#
# 21,32,28,29,41,29,23,54,51,77
#
# 22,29,23,23,31,27,25,47,44,67
#
# 23,27,21,27,29,32,22,47,44,67
#
# 0,42,38,30,41,29,27,62,58,87
#
# 1,41,34,32,35,32,24,59,55,84
#
# 2,30,27,33,47,32,28,59,55,83
#
# 3,43,37,37,39,24,24,61,57,86
#
# 4,33,30,27,39,27,31,56,52,79
#
# 5,25,21,30,46,23,21,49,46,71
#
# 6,25,18,29,40,25,32,50,47,72
#
# 7,28,21,37,38,27,24,52,49,74
#
# 8,36,35,30,38,33,26,59,55,84
#
# 9,40,33,30,30,27,29,56,53,80
#
# 10,31,28,35,44,34,23,58,54,83
#
# 11,22,15,26,31,31,22,44,41,62
#
# 12,29,23,36,45,32,27,57,54,81
#
# 13,30,28,35,40,24,22,53,50,76
#
# 14,30,25,30,42,35,33,58,54,83
#
# 15,30,25,32,47,30,26,57,53,80
#
# 16,39,37,34,37,28,31,61,58,87
#
# 17,21,20,22,35,34,29,48,45,68
#
# 18,33,30,29,42,28,27,56,53,80
#
# 19,36,28,33,46,23,30,58,55,83
#
# 20,28,26,25,36,26,21,48,45,69
#
# 21,35,32,30,40,29,21,56,52,79
#
# 22,25,18,25,32,27,22,44,42,63
#
# 23,20,13,27,33,21,24,41,38,59
#
# 0,25,18,35,40,24,31,51,48,74
#
# 1,37,29,36,38,24,22,55,52,79
#
# 2,40,32,35,45,29,29,63,58,89
#
# 3,43,35,37,42,29,27,63,60,90
#
# 4,34,28,36,40,24,22,55,51,78
#
# 5,29,27,34,51,31,30,60,56,86
#
# 6,26,20,37,44,31,27,55,52,78
#
# 7,42,39,29,31,29,28,59,55,84
#
# 8,25,17,28,33,27,22,45,42,65
#
# 9,31,29,28,40,32,24,55,51,78
#
# 10,40,34,35,44,34,32,65,61,93
#
# 11,40,36,34,46,26,28,63,58,89
#
# 12,37,31,32,43,35,24,60,56,86
#
# 13,24,16,24,41,29,23,47,44,66
#
# 14,25,17,26,34,33,30,49,46,70
#
# 15,23,21,29,30,29,24,46,44,66
#
# 16,35,33,26,38,25,22,53,50,76
#
# 17,27,26,30,44,33,22,54,51,77
#
# 18,22,16,23,27,33,30,45,42,64
#
# 19,21,14,29,29,31,23,44,41,62
#
# 20,33,31,33,47,28,22,58,54,82
#
# 21,27,22,32,40,23,27,51,48,72
#
# 22,34,33,23,40,20,31,54,50,77
#
# 23,26,24,19,27,28,24,44,41,63
#
# 0,27,20,35,49,29,25,55,52,78
#
# 1,34,31,30,32,24,21,51,48,73
#
# 2,40,36,27,34,32,24,57,54,82
#
# 3,30,28,37,48,27,33,60,57,86
#
# 4,43,36,32,44,32,32,65,61,93
#
# 5,39,36,32,42,27,29,61,57,87
#
# 6,30,23,34,37,33,27,55,51,78
#
# 7,36,31,36,52,30,27,63,59,90
#
# 8,27,19,34,47,22,26,52,49,74
#
# 9,23,17,35,38,28,30,51,48,72
#
# 10,22,18,36,40,31,33,54,50,76
#
# 11,37,31,28,32,33,27,56,52,80
#
# 12,25,20,25,33,32,26,48,45,68
#
# 13,32,24,33,43,31,23,55,52,79
#
# 14,38,37,35,40,29,31,63,58,89
#
# 15,39,38,25,26,26,24,53,50,75
#
# 16,23,22,33,33,23,24,47,44,67
#
# 17,37,36,22,36,29,30,57,53,80
#
# 18,32,31,25,37,23,31,53,50,76
#
# 19,32,31,31,40,32,33,59,56,84
#
# 20,35,31,21,29,29,24,50,47,72
#
# 21,32,29,32,40,29,23,55,52,78
#
# 22,26,24,32,39,30,24,52,49,74
#
# 23,35,34,27,28,30,27,54,50,77
#
# 0,30,29,29,37,29,31,55,52,78
#
# 1,42,36,33,44,33,21,62,58,89
#
# 2,34,26,34,34,33,30,57,53,81
#
# 3,42,41,27,40,24,21,58,54,83
#
# 4,28,23,28,32,28,24,48,46,69
#
# 5,41,36,26,37,35,22,59,55,83
#
# 6,36,28,33,39,25,28,56,53,80
#
# 7,32,31,35,36,24,27,55,52,78
#
# 8,27,24,26,35,33,31,52,49,75
#
# 9,32,24,34,34,33,28,55,52,78
#
# 10,22,20,29,40,24,27,48,45,69
#
# 11,38,30,25,27,29,24,51,48,74
#
# 12,41,33,26,32,23,31,55,52,79
#
# 13,23,16,27,41,28,29,49,46,69
#
# 14,41,38,23,25,26,26,53,50,76
#
# 15,24,19,31,31,33,28,49,46,71
#
# 16,26,23,25,33,26,23,46,44,66
#
# 17,31,27,25,34,33,25,52,49,74
#
# 18,35,32,32,37,32,25,57,54,82
#
# 19,36,35,21,21,25,22,48,44,68
#
# 20,25,22,22,38,33,32,51,48,73
#
# 21,23,19,25,37,25,31,48,44,68
#
# 22,37,30,19,28,26,21,48,45,68
#
# 23,21,17,23,33,29,29,45,42,65
#
# 0,28,22,37,50,27,22,55,52,79
#
# 1,29,23,31,42,23,24,51,48,73
#
# 2,35,33,36,37,32,32,61,57,87
#
# 3,31,23,24,40,25,32,52,49,74
#
# 4,37,32,30,41,29,27,58,55,83
#
# 5,42,38,37,45,31,31,67,62,95
#
# 6,41,39,38,45,26,23,63,59,90
#
# 7,38,33,25,36,35,31,59,55,84
#
# 8,31,24,34,41,23,22,52,49,74
#
# 9,34,33,34,34,30,23,56,52,80
#
# 10,27,26,36,41,25,26,54,50,77
#
# 11,37,32,26,26,27,25,51,48,74
#
# 12,24,23,27,27,26,32,47,44,68
#
# 13,35,30,30,41,24,23,54,51,78
#
# 14,31,23,30,43,31,29,56,52,79
#
# 15,32,24,27,38,31,29,54,50,77
#
# 16,31,25,30,34,34,30,55,51,78
#
# 17,38,31,22,33,35,26,55,52,78
#
# 18,38,36,25,31,23,28,54,50,77
#
# 19,31,28,30,37,32,24,54,51,77
#
# 20,29,21,28,28,23,32,48,45,68
#
# 21,23,17,28,37,30,29,49,46,69
#
# 22,19,15,25,35,22,27,42,40,61
#
# 23,33,25,26,38,24,23,50,47,72
#
# 0,27,24,35,53,23,22,55,51,78
#
# 1,29,23,26,41,29,20,50,47,71
#
# 2,26,18,35,45,31,30,55,52,78
#
# 3,27,23,35,46,35,22,56,52,80
#
# 4,30,27,32,37,24,31,54,50,77
#
# 5,29,24,37,44,29,30,57,54,82
#
# 6,31,28,32,32,26,31,54,50,76
#
# 7,31,23,25,31,35,27,51,48,73
#
# 8,38,30,28,34,30,21,54,50,77
#
# 9,30,28,36,51,32,31,62,58,88
#
# 10,38,34,35,39,25,33,61,57,86
#
# 11,39,38,32,36,31,28,61,57,86
#
# 12,29,22,25,37,32,26,51,48,72
#
# 13,27,24,28,35,35,30,53,50,76
#
# 14,38,33,35,39,29,28,60,56,86
#
# 15,26,23,25,31,25,25,46,43,66
#
# 16,31,29,26,34,30,22,51,48,73
#
# 17,23,15,32,47,28,25,51,47,72
#
# 18,20,12,30,45,32,29,50,47,71
#
# 19,19,18,24,27,32,25,43,40,62
#
# 20,36,33,22,23,21,24,47,44,68
#
# 21,26,23,26,26,32,33,49,46,71
#
# 22,26,19,30,39,29,31,52,48,74
#
# 23,19,17,29,46,33,26,51,47,72
#
# 0,30,23,28,44,27,26,53,50,75
#
# 1,44,39,36,44,28,22,63,60,90
#
# 2,34,27,28,30,28,23,51,47,72
#
# 3,29,24,36,42,29,29,56,53,80
#
# 4,38,37,30,40,30,29,61,57,86
#
# 5,33,31,28,44,29,32,59,55,83
#
# 6,39,36,34,50,32,27,65,61,92
#
# 7,33,28,37,45,31,23,59,55,83
#
# 8,28,21,25,40,32,22,50,47,71
#
# 9,36,34,27,43,25,23,56,52,80
#
# 10,34,31,26,43,33,30,59,55,83
#
# 11,43,38,37,40,34,24,64,60,92
#
# 12,30,27,34,47,32,22,57,54,81
#
# 13,40,33,25,33,30,33,58,54,82
#
# 14,31,27,28,45,29,31,57,53,81
#
# 15,23,19,29,36,29,28,49,46,69
#
# 16,24,17,22,35,31,24,45,43,65
#
# 17,25,16,30,35,27,29,48,45,69
#
# 18,24,20,32,42,23,27,50,47,71
#
# 19,39,33,34,46,27,27,61,58,87
#
# 20,32,27,28,45,27,31,57,53,80
#
# 21,18,17,26,43,30,30,49,46,69
#
# 22,31,24,28,46,24,29,54,51,77
#
# 23,19,12,26,34,29,20,42,39,59
#
# 0,26,20,33,42,32,22,52,49,74
#
# 1,29,27,29,43,32,25,55,52,78
#
# 2,38,35,27,27,27,26,54,50,76
#
# 3,41,37,33,43,35,30,65,61,93
#
# 4,40,31,28,47,23,23,57,54,81
#
# 5,26,20,29,30,30,30,49,46,70
#
# 6,23,19,25,25,23,28,42,40,61
#
# 7,24,21,26,33,32,31,50,46,71
#
# 8,28,26,30,44,26,28,54,51,77
#
# 9,25,20,34,43,32,23,53,49,75
#
# 10,27,19,32,44,24,30,52,49,75
#
# 11,34,33,37,46,23,30,60,57,86
#
# 12,33,27,32,42,34,32,60,56,84
#
# 13,30,29,24,28,34,31,52,49,75
#
# 14,25,23,25,42,29,34,53,50,75
#
# 15,32,24,33,42,26,21,53,50,75
#
# 16,21,18,23,25,31,26,43,40,61
#
# 17,28,22,31,32,35,24,51,48,73
#
# 18,30,21,28,45,22,28,52,48,74
#
# 19,39,38,23,40,23,22,55,52,78
#
# 20,19,15,27,27,30,23,42,39,60
#
# 21,39,36,27,37,26,24,56,53,80
#
# 22,25,17,24,25,25,26,42,40,60
#
# 23,31,29,31,33,26,23,51,48,74
#
# 0,41,38,26,29,32,28,58,54,82
#
# 1,36,32,34,46,32,20,60,56,84
#
# 2,44,38,32,46,29,26,64,60,91
#
# 3,24,21,31,35,36,21,50,47,71
#
# 4,26,25,33,51,33,23,57,53,81
#
# 5,29,21,34,37,35,21,53,49,75
#
# 6,34,26,38,40,36,31,61,57,87
#
# 7,39,34,30,37,32,22,58,54,82
#
# 8,38,36,35,41,28,24,60,56,86
#
# 9,34,33,29,42,36,22,58,55,83
#
# 10,38,36,26,32,34,30,58,55,83
#
# 11,29,28,27,36,33,21,52,48,74
#
# 12,27,21,33,43,31,23,53,50,75
#
# 13,36,28,33,33,32,31,57,54,82
#
# 14,29,27,33,44,27,21,54,50,77
#
# 15,24,21,34,34,31,21,49,46,70
#
# 16,39,37,23,35,32,21,56,52,79
#
# 17,32,25,23,29,22,31,48,45,69
#
# 18,24,15,31,45,34,27,52,49,75
#
# 19,27,25,28,44,22,25,51,48,72
#
# 20,22,19,30,38,23,23,46,43,66
#
# 21,33,27,24,43,30,30,56,52,79
#
# 22,27,20,26,30,28,33,49,46,69
#
# 23,27,20,31,32,21,22,45,43,65
#
# 0,44,36,31,44,35,24,64,60,90
#
# 1,41,35,30,35,30,26,59,55,83
#
# 2,38,32,25,34,35,34,59,55,84
#
# 3,36,35,27,27,31,23,53,50,76
#
# 4,41,36,31,41,24,30,60,57,86
#
# 5,29,22,33,42,35,25,55,52,79
#
# 6,42,37,28,38,35,27,62,58,87
#
# 7,44,37,38,45,25,25,64,60,90
#
# 8,45,42,36,46,24,33,67,63,96
#
# ...
#
# 6,23,21,33,37,32,33,53,50,76
#
# 7,27,20,26,30,32,31,49,46,71
#
# 8,23,13,40,49,23,30,53,50,75
#
# 9,28,20,41,48,29,23,56,53,80
#
# 10,22,20,29,40,34,30,52,49,74
#
# 11,39,35,32,47,31,31,64,60,91
#
# 12,41,36,39,48,34,27,67,63,95
#
# 13,26,23,32,40,35,32,56,52,80
#
# 14,33,25,32,38,31,25,55,51,78
#
# 15,45,39,35,41,29,27,64,60,92
#
# 16,44,35,26,26,23,26,54,50,76
#
# 17,20,15,36,44,34,34,54,51,78
#
# 18,20,19,36,46,26,29,52,49,75
#
# 19,40,33,27,47,30,32,62,58,89
#
# 20,25,16,23,38,26,23,45,42,64
#
# 21,27,24,23,27,26,28,46,43,66
#
# 22,39,36,25,25,29,21,52,49,74
#
# 23,23,18,22,23,21,33,42,39,59
#
# 0,45,43,28,44,22,36,65,61,92
#
# 1,34,26,31,45,29,35,60,56,84
#
# 2,36,31,28,38,26,25,55,51,78
#
# 3,43,35,27,47,30,30,63,59,90
#
# 4,45,43,30,32,35,31,64,60,92
#
# 5,28,25,40,56,25,33,62,58,87
#
# 6,46,42,35,35,30,23,63,59,89
#
# 7,25,24,27,32,35,31,52,48,74
#
# 8,42,34,40,56,39,33,73,68,103
#
# 9,30,25,40,60,38,26,65,61,93
#
# 10,33,27,35,50,26,33,61,57,86
#
# 11,33,31,28,50,38,21,60,56,85
#
# 12,41,31,28,36,24,34,58,54,82
#
# 13,41,37,38,54,30,32,69,65,98
#
# 14,41,40,31,50,36,21,65,61,93
#
# 15,45,44,35,46,31,25,67,63,96
#
# 16,40,39,34,52,35,25,67,63,95
#
# 17,32,25,24,36,26,36,53,50,76
#
# 18,34,24,30,37,33,36,58,54,82
#
# 19,41,34,31,47,30,25,62,58,88
#
# 20,29,19,28,38,33,34,54,50,77
#
# 21,20,12,35,44,27,30,50,47,71
#
# 22,29,23,21,22,29,25,44,42,63
#
# 23,26,19,19,27,23,36,45,42,63
#
# 0,24,15,34,37,37,27,52,48,74
#
# 1,43,40,37,58,31,23,69,65,98
#
# 2,31,28,39,49,34,25,61,58,87
#
# 3,24,21,25,31,29,27,47,44,66
#
# 4,40,38,35,50,23,23,62,58,89
#
# 5,39,30,39,48,36,33,67,63,95
#
# 6,47,42,29,49,36,31,70,65,99
#
# 7,40,34,34,38,32,37,64,60,91
#
# 8,28,24,35,41,23,36,56,52,79
#
# 9,37,31,34,39,36,23,60,56,84
#
# 10,45,38,33,52,36,23,68,63,96
#
# 11,39,33,39,47,39,34,69,64,98
#
# 12,39,29,28,47,22,21,55,52,79
#
# 13,35,33,26,34,38,37,60,57,86
#
# 14,28,21,35,54,38,31,62,58,87
#
# 15,45,42,38,42,38,35,72,67,101
#
# 16,37,28,37,58,28,31,65,61,93
#
# 17,21,19,27,48,24,23,48,45,69
#
# 18,38,32,29,33,30,27,56,53,80
#
# 19,26,24,32,35,25,27,50,47,72
#
# 20,22,20,29,38,37,25,51,48,72
#
# 21,41,36,30,36,29,26,59,55,84
#
# 22,39,36,30,38,32,25,60,56,84
#
# 23,32,23,23,23,26,23,45,42,63
#
# 0,46,41,35,43,31,36,69,65,98
#
# 1,40,38,30,30,24,25,56,52,79
#
# 2,39,36,25,47,32,23,60,56,86
#
# 3,25,19,27,39,24,33,50,46,71
#
# 4,28,25,39,59,30,35,64,60,92
#
# 5,48,37,28,38,33,22,61,58,87
#
# 6,37,36,31,34,30,25,57,54,82
#
# 7,38,37,33,44,38,37,68,63,96
#
# 8,49,42,35,39,36,29,69,64,97
#
# 9,40,37,32,38,34,23,61,57,86
#
# 10,45,41,33,44,28,27,65,61,92
#
# 11,32,29,36,41,26,31,58,54,83
#
# 12,46,45,30,47,29,21,65,61,92
#
# 13,39,29,28,37,32,36,60,56,85
#
# 14,37,29,34,41,28,36,61,57,87
#
# 15,25,15,28,42,36,27,51,48,74
#
# 16,27,20,30,39,26,37,53,50,76
#
# 17,27,18,31,50,28,24,53,50,75
#
# 18,32,28,30,49,29,28,58,55,83
#
# 19,29,19,26,35,31,37,53,49,75
#
# 20,20,17,23,32,37,31,48,44,68
#
# 21,32,31,23,35,26,30,53,49,75
#
# 22,31,23,35,53,23,29,58,54,82
#
# 23,24,20,24,46,37,25,52,49,75
#
# 0,44,37,29,49,33,33,67,63,95
#
# 1,48,39,29,33,28,32,62,58,89
#
# 2,38,36,39,51,23,34,66,62,93
#
# 3,41,39,39,51,28,32,69,64,97
#
# 4,48,40,25,46,25,27,63,59,89
#
# 5,48,41,31,49,31,22,66,62,94
#
# 6,23,20,32,53,37,32,59,55,83
#
# 7,49,41,31,34,27,24,61,58,87
#
# 8,40,39,40,50,26,26,66,62,93
#
# 9,28,25,36,57,30,37,63,60,90
#
# 10,27,19,28,51,38,28,57,53,81
#
# 11,45,36,33,48,32,29,66,62,95
#
# 12,44,43,25,34,27,23,58,55,83
#
# 13,37,36,27,40,29,27,58,55,83
#
# 14,35,29,37,39,38,35,63,60,90
#
# 15,43,40,36,39,32,36,67,63,96
#
# 16,43,42,29,51,31,24,66,61,93
#
# 17,26,22,35,38,30,33,55,51,78
#
# 18,18,13,37,55,22,28,51,48,74
#
# 19,40,29,29,49,37,35,65,61,93
#
# 20,20,13,35,49,31,26,52,48,74
#
# 21,24,17,32,33,22,27,46,43,66
#
# 22,18,17,36,53,37,22,54,51,78
#
# 23,26,18,24,32,29,25,46,43,65
#
# 0,41,40,38,50,27,22,65,61,92
#
# 1,46,36,35,43,22,22,61,57,86
#
# 2,51,45,34,42,34,32,71,66,101
#
# 3,41,35,31,45,31,22,61,57,87
#
# 4,29,26,28,30,39,32,55,51,78
#
# 5,33,23,35,49,26,34,60,56,84
#
# 6,33,32,37,56,30,20,62,58,88
#
# 7,43,36,30,37,35,25,61,58,87
#
# 8,41,39,29,49,23,24,61,57,87
#
# 9,41,36,30,46,35,26,64,60,90
#
# 10,45,37,36,57,26,33,70,65,99
#
# 11,42,36,28,41,30,33,63,58,89
#
# 12,31,21,28,32,29,24,49,46,70
#
# 13,42,37,27,36,24,27,57,54,82
#
# 14,33,28,38,38,34,30,60,56,85
#
# 15,33,32,30,34,35,31,58,54,83
#
# 16,38,33,33,34,24,22,55,51,78
#
# 17,19,10,29,33,25,30,43,41,62
#
# 18,32,25,36,36,38,30,59,55,83
#
# 19,44,37,25,45,24,22,59,55,83
#
# 20,30,23,37,55,23,31,59,56,84
#
# 21,43,33,32,36,28,28,60,56,84
#
# 22,44,34,23,25,33,26,55,52,78
#
# 23,25,21,30,30,27,25,47,44,67
#
# 0,28,20,41,41,22,22,52,48,74
#
# 1,47,41,37,49,32,25,69,64,98
#
# 2,50,40,27,31,34,30,63,59,90
#
# 3,28,23,36,53,34,35,62,58,89
#
# 4,33,32,41,63,32,24,67,63,95
#
# 5,38,29,28,41,34,33,60,57,86
#
# 6,45,35,41,57,25,26,68,64,97
#
# 7,31,26,29,38,34,25,54,51,78
#
# 8,34,26,39,43,31,36,62,58,89
#
# 9,23,18,33,54,36,34,59,55,84
#
# 10,30,28,37,40,36,23,58,54,82
#
# 11,31,24,38,56,29,28,61,58,87
#
# 12,37,34,38,52,36,31,68,64,96
#
# 13,34,30,37,37,34,37,62,58,89
#
# 14,28,25,31,39,23,24,51,47,72
#
# 15,32,28,23,35,30,31,53,50,76
#
# 16,34,29,27,29,25,37,54,50,77
#
# 17,36,27,36,49,24,25,59,55,83
#
# 18,21,12,24,32,33,23,43,40,62
#
# 19,32,28,22,34,29,34,53,50,76
#
# 20,24,20,34,46,28,34,55,52,79
#
# 21,44,41,23,41,23,21,57,54,82
#
# 22,20,16,26,48,25,26,48,45,68
#
# 23,36,29,24,33,30,22,52,48,74
#
# 0,39,29,39,42,32,37,65,61,92
#
# 1,51,47,35,36,27,22,65,61,92
#
# 2,42,40,34,49,29,26,66,61,93
#
# 3,40,31,28,41,34,20,58,54,82
#
# 4,44,33,38,46,36,23,66,61,93
#
# 5,43,33,33,55,37,28,68,64,97
#
# 6,48,47,34,52,29,27,71,66,100
#
# 7,23,19,35,36,27,24,49,46,69
#
# 8,37,33,25,30,34,33,57,54,81
#
# 9,43,39,41,51,33,23,69,64,97
#
# 10,43,35,38,51,31,25,66,62,95
#
# 11,29,21,29,38,38,35,57,53,80
#
# 12,43,41,38,44,24,33,66,62,95
#
# 13,43,37,38,40,38,36,69,65,98
#
# 14,35,29,30,46,33,36,62,58,89
#
# 15,34,32,34,51,26,23,60,56,84
#
# 16,39,36,29,36,30,31,60,56,85
#
# 17,39,32,27,33,37,37,61,57,87
#
# 18,19,12,31,39,33,36,51,47,72
#
# 19,19,16,24,29,27,28,42,40,61
#
# 20,40,30,22,43,29,25,56,53,80
#
# 21,21,10,28,31,37,22,44,42,63
#
# 22,41,34,28,29,33,36,60,56,85
#
# 23,38,36,19,20,35,34,54,51,77
#
# 0,34,33,25,39,23,35,56,53,80
#
# 1,39,32,25,31,24,21,51,48,73
#
# 2,44,35,41,47,33,33,69,65,99
#
# 3,39,38,39,52,25,21,64,60,90
#
# 4,36,33,26,45,38,24,60,56,86
#
# 5,33,26,39,62,29,36,67,63,95
#
# 6,30,23,34,52,37,24,60,56,84
#
# 7,25,21,28,31,28,34,50,46,71
#
# 8,36,32,25,42,32,31,59,55,84
#
# 9,25,22,28,35,32,21,48,46,69
#
# 10,23,13,37,50,33,32,56,52,80
#
# 11,42,37,30,50,30,28,65,60,92
#
# 12,39,36,39,42,35,23,64,60,90
#
# 13,39,29,34,57,37,30,67,63,96
#
# 14,27,17,33,45,23,26,51,48,72
#
# 15,20,13,36,49,32,31,54,50,77
#
# 16,44,38,22,32,28,31,58,54,83
#
# 17,34,27,24,36,39,22,54,51,77
#
# 18,19,17,35,53,26,25,52,49,74
#
# 19,28,23,25,34,29,30,50,47,72
#
# 20,29,20,33,49,27,24,54,51,77
#
# 21,42,41,20,38,29,37,62,58,87
#
# 22,24,21,35,54,33,35,60,56,86
#
# 23,39,31,24,28,22,34,53,50,75
#
# 0,46,40,34,38,38,23,65,61,93
#
# 1,40,29,26,42,37,31,61,57,87
#
# 2,27,20,29,53,30,25,55,51,78
#
# 3,46,36,36,41,27,23,62,58,89
#
# 4,50,43,31,36,26,28,64,60,90
#
# 5,43,32,25,43,31,30,61,57,86
#
# 6,29,23,34,38,31,36,57,53,81
#
# 7,48,45,28,30,31,23,61,57,87
#
# 8,24,19,36,53,31,20,54,51,78
#
# 9,29,27,41,58,34,24,63,60,90
#
# 10,22,16,33,50,34,36,57,53,81
#
# 11,28,23,26,30,39,37,54,51,78
#
# 12,48,41,40,53,28,37,74,69,104
#
# 13,43,41,38,62,34,24,72,68,102
#
# 14,41,39,29,32,23,23,56,52,79
#
# 15,45,44,27,30,25,33,61,57,86
#
# 16,28,20,26,47,37,26,55,51,78
#
# 17,44,35,28,39,39,38,66,62,95
#
# 18,45,43,34,37,30,34,66,62,95
#
# 19,33,22,21,23,26,23,44,41,63
#
# 20,43,39,35,40,32,22,63,59,89
#
# 21,28,19,32,33,37,27,52,49,75
#
# 22,27,19,31,43,37,36,57,54,82
#
# 23,20,12,32,44,22,32,48,45,69
#
# 0,36,35,30,32,30,34,59,55,83
#
# 1,31,29,31,50,35,20,58,55,83
#
# 2,47,45,34,36,32,21,64,60,91
#
# 3,35,29,37,38,33,21,57,54,82
#
# 4,40,32,38,59,35,37,72,67,102
#
# 5,43,42,33,34,22,28,60,56,86
#
# 6,49,48,34,34,31,26,66,62,94
#
# 7,31,20,39,57,40,25,63,59,90
#
# 8,48,37,25,34,33,35,63,59,90
#
# 9,42,41,41,54,23,36,71,66,100
#
# 10,30,26,27,49,27,37,58,55,83
#
# 11,22,15,32,32,37,25,48,46,69
#
# 12,46,42,27,30,31,22,59,55,84
#
# 13,35,32,26,49,31,29,60,56,86
#
# 14,23,14,31,46,29,33,52,49,75
#
# 15,41,35,38,47,22,33,64,60,92
#
# 16,28,27,26,27,39,31,53,50,75
#
# 17,43,38,38,46,26,32,66,62,95
#
# 18,31,22,35,45,24,29,55,52,79
#
# 19,44,33,36,51,34,32,69,64,97
#
# 20,29,19,24,46,32,31,54,50,77
#
# 21,28,22,28,40,22,35,52,49,74
#
# 22,29,22,25,37,23,26,48,45,69
#
# 23,40,32,22,44,27,23,56,52,80
#
# 0,51,49,31,33,28,20,63,59,90
#
# 1,42,36,27,42,25,20,57,54,81
#
# 2,26,17,33,44,36,21,53,49,75
#
# 3,41,37,36,43,38,33,68,64,96
#
# 4,35,31,30,30,27,33,55,52,79
#
# 5,44,39,40,56,34,31,73,68,103
#
# 6,23,12,40,49,37,32,57,54,82
#
# 7,28,26,42,56,25,25,60,56,86
#
# 8,39,38,32,49,31,35,67,62,95
#
# 9,31,30,36,42,26,24,56,53,80
#
# 10,44,42,38,57,28,22,69,64,98
#
# 11,30,19,38,44,31,22,55,51,78
#
# 12,27,23,37,57,38,36,65,61,92
#
# 13,26,24,25,33,28,27,48,46,69
#
# 14,30,23,28,37,40,24,54,51,77
#
# 15,27,22,26,26,26,30,47,44,66
#
# 16,37,33,26,46,32,21,58,54,83
#
# 17,40,36,39,44,23,27,62,58,89
#
# 18,43,34,21,41,29,29,59,55,83
#
# 19,39,35,22,34,35,24,56,53,80
#
# 20,39,31,27,39,38,35,62,58,89
#
# 21,44,40,21,29,21,24,53,50,76
#
# 22,20,14,22,43,27,31,47,44,66
#
# 23,37,36,33,37,33,36,63,59,90
#
# 0,28,20,28,50,24,33,54,51,78
#
# 1,40,37,35,46,27,31,64,60,92
#
# 2,38,29,38,40,39,33,65,60,92
#
# 3,27,19,40,63,22,28,59,56,84
#
# 4,38,27,40,45,23,26,59,56,84
#
# 5,26,20,41,57,26,27,59,55,83
#
# 6,32,31,41,65,32,28,68,64,97
#
# 7,33,30,27,47,28,25,57,53,80
#
# 8,24,23,30,33,31,25,49,46,71
#
# 9,39,30,31,36,35,25,58,55,83
#
# 10,22,17,26,41,28,26,48,44,68
#
# 11,27,19,35,54,24,23,54,51,77
#
# 12,22,12,24,39,23,30,45,42,63
#
# 13,22,15,41,60,25,31,58,54,82
#
# 14,30,26,39,55,27,28,61,57,87
#
# 15,21,15,26,40,36,36,52,48,74
#
# 16,39,36,27,51,29,37,65,61,93
#
# 17,21,15,28,44,34,28,51,47,72
#
# 18,32,23,31,46,36,32,60,56,84
#
# 19,47,36,28,50,28,33,66,62,94
#
# 20,22,18,32,48,28,38,55,52,79
#
# 21,41,34,21,37,35,29,59,55,83
#
# 22,35,34,31,51,21,32,61,57,86
#
# 23,31,26,28,46,32,23,55,52,79
#
# 0,41,35,26,45,38,23,62,58,88
#
# 1,47,43,35,56,38,26,73,68,104
#
# 2,34,23,35,43,30,29,58,54,82
#
# 3,31,29,42,67,29,28,67,63,96
#
# 4,48,46,42,56,26,20,71,66,101
#
# 5,42,36,26,41,28,28,60,56,85
#
# 6,23,19,31,31,28,26,47,44,67
#
# 7,49,41,26,26,28,31,60,56,85
#
# 8,48,43,26,30,26,35,62,58,88
#
# 9,22,16,42,58,33,38,62,58,89
#
# 10,34,28,30,44,23,20,53,50,76
#
# 11,23,16,31,37,30,32,50,47,72
#
# 12,41,36,25,49,26,24,60,56,85
#
# 13,29,24,38,52,28,23,58,54,82
#
# 14,33,31,38,58,32,34,67,63,96
#
# 15,38,31,38,60,24,38,68,64,97
#
# 16,29,21,30,39,38,22,53,50,76
#
# 17,37,35,34,38,26,23,57,54,82
#
# 18,42,38,23,33,37,28,60,56,85
#
# 19,23,14,32,44,37,30,54,50,76
#
# 20,26,18,30,41,36,27,53,50,75
#
# 21,37,31,31,55,38,32,67,62,95
#
# 22,27,23,23,26,36,34,50,47,72
#
# 23,23,19,24,28,34,36,49,46,69
#
# 0,26,17,24,43,29,24,48,46,69
#
# 1,38,34,41,49,24,36,66,62,94
#
# 2,48,42,33,50,31,31,70,66,99
#
# 3,46,35,25,50,32,23,63,59,89
#
# 4,42,34,29,48,37,37,68,63,96
#
# 5,34,24,41,48,35,25,62,58,87
#
# 6,31,27,25,35,33,31,54,51,77
#
# 7,31,30,39,42,37,26,61,57,87
#
# 8,39,38,28,33,28,31,59,55,83
#
# 9,23,17,39,39,40,24,54,51,77
#
# 10,47,45,30,47,30,35,70,65,99
#
# 11,37,29,29,50,32,39,64,60,92
#
# 12,26,22,33,48,28,28,55,52,78
#
# 13,37,35,29,52,37,27,65,60,92
#
# 14,37,32,23,26,34,36,56,52,80
#
# 15,36,33,33,35,28,30,58,54,83
#
# 16,29,24,32,40,35,36,58,55,83
#
# 17,39,33,26,44,25,34,60,56,85
#
# 18,35,24,28,47,39,21,58,54,82
#
# 19,42,38,36,51,26,34,68,63,96
#
# 20,22,20,23,25,34,29,45,43,65
#
# 21,22,17,22,28,22,24,40,38,57
#
# 22,23,18,20,31,37,34,48,46,69
#
# 23,23,21,34,44,24,28,52,48,74
#
# 0,47,39,30,35,39,24,64,60,90
#
# 1,51,43,36,41,36,22,68,64,97
#
# 2,24,19,36,46,23,24,51,48,73
#
# 3,25,21,25,37,25,22,46,43,66
#
# 4,41,34,42,65,40,36,77,72,109
#
# 5,50,41,29,46,30,35,69,64,98
#
# 6,42,33,31,53,26,34,65,61,93
#
# 7,32,26,31,52,23,25,56,53,80
#
# 8,41,33,25,25,27,34,55,52,78
#
# 9,28,17,31,45,23,25,50,47,72
#
# 10,34,25,30,50,40,23,60,56,86
#
# 11,26,25,40,40,32,22,55,52,78
#
# 12,21,19,29,51,25,27,51,48,73
#
# 13,45,34,24,37,33,30,60,57,86
#
# 14,35,32,37,56,40,29,68,64,97
#
# 15,45,35,41,63,28,24,70,66,100
#
# 16,40,34,23,39,23,21,54,50,76
#
# 17,48,41,38,39,24,34,67,62,95
#
# 18,46,37,24,27,23,34,57,53,81
#
# 19,30,23,27,35,35,36,55,52,79
#
# 20,31,21,32,33,23,29,50,47,72
#
# 21,38,29,36,38,25,22,56,52,80
#
# 22,46,41,21,41,31,35,64,60,91
#
# 23,23,20,32,48,24,25,51,48,73
#
# 0,32,26,37,57,30,21,60,57,86
#
# 1,35,30,28,29,36,31,56,53,80
#
# 2,34,33,29,42,30,30,59,55,84
#
# 3,30,28,27,31,23,35,52,48,74
#
# 4,32,25,36,42,39,29,60,57,86
#
# 5,38,32,28,35,40,32,61,57,87
#
# 6,38,31,35,39,30,21,58,54,82
#
# 7,37,35,30,55,30,24,63,59,89
#
# 8,48,39,32,54,34,22,68,64,97
#
# 9,46,41,28,49,27,36,68,63,96
#
# 10,28,24,31,45,28,35,57,53,81
#
# 11,28,19,36,41,30,25,53,50,76
#
# 12,49,42,41,44,40,21,71,66,100
#
# 13,30,20,35,54,35,39,63,60,90
#
# 14,33,23,23,24,37,35,52,49,74
#
# 15,41,33,24,34,24,36,57,54,81
#
# 16,22,17,31,53,37,37,59,55,83
#
# 17,38,32,32,45,38,36,66,62,93
#
# 18,35,31,27,39,27,32,57,53,81
#
# 19,27,20,27,33,24,34,49,46,70
#
# 20,30,26,37,43,38,28,60,56,86
#
# 21,29,19,23,32,35,24,48,45,69
#
# 22,20,13,35,49,20,22,47,44,68
#
# 23,38,29,35,57,37,38,70,65,99
#
# 0,34,28,34,47,26,33,60,56,86
#
# 1,39,35,36,43,24,38,64,60,91
#
# 2,48,38,42,55,29,23,70,66,99
#
# 3,27,21,39,57,25,20,56,53,80
#
# 4,25,13,33,48,31,28,53,50,75
#
# 5,39,35,40,43,30,31,65,61,92
#
# 6,34,23,26,31,38,33,55,52,78
#
# 7,33,25,42,53,26,30,62,58,89
#
# 8,39,32,31,54,41,30,68,63,96
#
# 9,42,38,36,60,31,26,69,65,99
#
# 10,29,23,29,50,24,36,57,53,81
#
# 11,50,46,35,43,40,22,70,66,100
#
# 12,27,24,41,41,31,36,60,56,84
#
# 13,27,24,33,36,33,38,57,53,81
#
# 14,41,37,23,33,35,23,57,54,81
#
# 15,45,37,23,29,33,25,57,54,81
#
# 16,28,24,27,38,30,27,52,48,74
#
# 17,27,19,39,60,24,22,57,53,81
#
# 18,32,27,23,36,29,29,52,49,75
#
# 19,41,38,25,41,29,37,63,59,89
#
# 20,30,20,33,53,28,36,60,56,84
#
# 21,19,12,24,37,25,37,46,43,65
#
# 22,33,26,36,46,32,31,61,57,86
#
# 23,26,20,27,28,21,29,45,42,64
#
# 0,30,26,24,42,39,35,58,55,83
#
# 1,37,28,27,27,34,30,54,51,78
#
# 2,34,28,29,36,30,26,54,51,78
#
# 3,29,22,38,43,37,28,59,55,83
#
# 4,43,36,34,51,23,35,66,62,94
#
# 5,27,20,29,42,23,35,52,49,75
#
# 6,33,29,27,31,32,32,55,51,78
#
# 7,34,29,35,35,28,29,57,53,80
#
# 8,51,49,29,41,31,33,70,65,99
#
# 9,35,28,33,52,33,32,63,60,90
#
# 10,36,33,25,29,27,34,55,51,78
#
# 11,35,24,42,43,24,32,60,56,84
#
# 12,33,22,26,51,29,22,54,51,78
#
# 13,30,27,26,38,41,38,60,56,84
#
# 14,31,22,26,38,33,32,54,51,77
#
# 15,27,20,27,42,36,21,51,48,74
#
# 16,23,18,25,50,32,39,56,52,79
#
# 17,33,24,31,52,29,37,61,58,87
#
# 18,21,17,27,29,27,23,43,40,61
#
# 19,37,32,28,31,32,26,55,52,79
#
# 20,47,38,23,35,28,22,57,54,82
#
# 21,34,28,22,23,37,31,52,49,74
#
# 22,44,33,37,49,27,30,66,61,93
#
# 23,45,39,20,27,30,30,57,53,81
#
# 0,26,15,37,55,32,36,60,56,85
#
# 1,50,47,31,31,28,31,65,61,92
#
# 2,26,23,40,42,30,23,55,51,78
#
# 3,43,42,39,42,32,30,68,64,96
#
# 4,53,50,41,41,26,30,72,67,102
#
# 5,29,18,27,49,31,36,57,53,80
#
# 6,33,32,33,51,30,27,61,58,87
#
# 7,31,30,40,56,37,38,69,65,98
#
# 8,51,45,35,40,27,36,70,65,99
#
# 9,34,23,27,46,32,34,58,55,83
#
# 10,29,26,25,37,31,33,54,50,77
#
# 11,37,34,34,41,41,23,63,58,89
#
# 12,45,44,27,52,28,38,70,65,99
#
# 13,42,31,23,33,31,33,57,54,82
#
# 14,35,26,36,49,34,26,61,58,87
#
# 15,45,41,41,46,25,37,70,66,99
#
# 16,28,18,25,48,34,28,54,50,77
#
# 17,40,35,30,36,36,25,60,56,86
#
# 18,43,32,23,38,39,28,60,57,86
#
# 19,39,37,32,36,22,30,58,55,83
#
# 20,18,13,38,40,27,35,51,48,72
#
# 21,45,33,25,35,31,22,57,53,81
#
# 22,32,30,33,35,29,26,55,52,78
#
# 23,25,14,37,53,22,30,54,50,77
#
# 0,44,41,40,63,31,29,74,69,105
#
# 1,25,18,24,43,35,20,49,46,70
#
# 2,31,26,43,53,40,37,69,64,97
#
# 3,27,26,25,47,29,26,54,50,76
#
# 4,33,25,41,41,27,28,58,54,83
#
# 5,43,42,33,43,31,36,68,64,96
#
# 6,40,33,26,38,25,34,58,55,83
#
# 7,32,28,32,45,32,38,62,58,87
#
# 8,29,27,41,47,25,23,57,54,81
#
# 9,33,25,31,39,28,21,53,49,75
#
# 10,48,40,26,48,31,30,66,62,95
#
# 11,24,16,32,57,39,39,62,58,87
#
# 12,27,18,32,38,41,36,57,54,81
#
# 13,23,22,28,54,25,27,53,50,76
#
# 14,41,39,38,55,36,23,69,65,98
#
# 15,33,24,24,27,34,38,54,50,76
#
# 16,20,11,24,25,29,24,39,37,57
#
# 17,26,17,31,34,31,29,50,47,71
#
# 18,46,45,26,52,32,31,69,65,98
#
# 19,41,39,37,51,28,32,68,64,96
#
# 20,39,31,32,52,34,39,68,63,96
#
# 21,42,40,31,42,24,25,61,57,86
#
# 22,38,33,33,41,35,28,62,58,88
#
# 23,30,22,31,43,33,25,55,51,78
#
# 0,27,16,36,53,32,37,60,56,85
#
# 1,46,35,25,38,24,37,61,57,87
#
# 2,49,42,35,42,36,21,67,63,95
#
# 3,36,25,28,33,38,31,57,53,81
#
# 4,33,23,33,57,29,20,58,54,83
#
# 5,35,24,33,55,36,36,65,61,93
#
# 6,49,45,36,41,36,22,68,64,97
#
# 7,36,24,43,49,28,26,61,58,87
#
# 8,28,18,30,49,38,31,58,54,82
#
# 9,48,45,30,48,23,38,69,65,98
#
# 10,29,21,37,42,24,23,52,49,75
#
# 11,47,45,42,51,35,37,77,72,108
#
# 12,45,35,29,45,32,30,64,60,92
#
# 13,23,19,37,56,41,28,61,57,86
#
# 14,24,20,38,63,32,25,60,56,86
#
# 15,40,38,29,50,33,26,64,60,92
#
# 16,42,40,37,48,22,30,65,61,93
#
# 17,27,19,36,55,36,22,58,54,83
#
# 18,32,31,33,53,32,38,65,61,93
#
# 19,35,32,27,44,32,26,58,55,83
#
# 20,24,14,34,40,33,32,53,49,75
#
# 21,23,21,31,50,26,38,56,53,80
#
# 22,17,12,23,25,37,25,41,39,59
#
# 23,33,30,30,41,28,32,58,54,82

# %%
arq = open("meu_arquivo.txt","w+")
 
linhasParaOArquivo = ["linha 1","linha 2","linha 3", "linha 4","linha 5"]
 
for l in linhasParaOArquivo:
    arq.write(l)
    arq.write("\n")

arq.close()

# %% [markdown]
# ### JSON

# %%
import json

with open('produtos.json') as f:
    produtos = json.load(f)

# %%
type(produtos)
# Out:
# list

# %%
produtos
# Out:
# [{'id': '0001',
#   'type': 'donut',
#   'name': 'Cake',
#   'ppu': 0.55,
#   'batters': {'batter': [{'id': '1001', 'type': 'Regular'},
#     {'id': '1002', 'type': 'Chocolate'},
#     {'id': '1003', 'type': 'Blueberry'},
#     {'id': '1004', 'type': "Devil's Food"}]},
#   'topping': [{'id': '5001', 'type': 'None'},
#    {'id': '5002', 'type': 'Glazed'},
#    {'id': '5005', 'type': 'Sugar'},
#    {'id': '5007', 'type': 'Powdered Sugar'},
#    {'id': '5006', 'type': 'Chocolate with Sprinkles'},
#    {'id': '5003', 'type': 'Chocolate'},
#    {'id': '5004', 'type': 'Maple'}]},
#  {'id': '0002',
#   'type': 'donut',
#   'name': 'Raised',
#   'ppu': 0.55,
#   'batters': {'batter': [{'id': '1001', 'type': 'Regular'}]},
#   'topping': [{'id': '5001', 'type': 'None'},
#    {'id': '5002', 'type': 'Glazed'},
#    {'id': '5005', 'type': 'Sugar'},
#    {'id': '5003', 'type': 'Chocolate'},
#    {'id': '5004', 'type': 'Maple'}]},
#  {'id': '0003',
#   'type': 'donut',
#   'name': 'Old Fashioned',
#   'ppu': 0.55,
#   'batters': {'batter': [{'id': '1001', 'type': 'Regular'},
#     {'id': '1002', 'type': 'Chocolate'}]},
#   'topping': [{'id': '5001', 'type': 'None'},
#    {'id': '5002', 'type': 'Glazed'},
#    {'id': '5003', 'type': 'Chocolate'},
#    {'id': '5004', 'type': 'Maple'}]}]

# %%
df = pd.read_json('https://mdn.github.io/learning-area/javascript/oojs/json/superheroes.json')
df
# Out:
#           squadName    homeTown  formed   secretBase  active  \
# 0  Super Hero Squad  Metro City    2016  Super tower    True
# 1  Super Hero Squad  Metro City    2016  Super tower    True
# 2  Super Hero Squad  Metro City    2016  Super tower    True
#
#                                              members
# 0  {'name': 'Molecule Man', 'age': 29, 'secretIde...
# 1  {'name': 'Madame Uppercut', 'age': 39, 'secret...
# 2  {'name': 'Eternal Flame', 'age': 1000000, 'sec...

# %%
df['members']
# Out:
# 0    {'name': 'Molecule Man', 'age': 29, 'secretIde...
# 1    {'name': 'Madame Uppercut', 'age': 39, 'secret...
# 2    {'name': 'Eternal Flame', 'age': 1000000, 'sec...
# Name: members, dtype: object

# %%
df['members'].apply(pd.Series)
# Out:
#               name      age secretIdentity  \
# 0     Molecule Man       29      Dan Jukes
# 1  Madame Uppercut       39    Jane Wilson
# 2    Eternal Flame  1000000        Unknown
#
#                                               powers
# 0  [Radiation resistance, Turning tiny, Radiation...
# 1  [Million tonne punch, Damage resistance, Super...
# 2  [Immortality, Heat Immunity, Inferno, Teleport...

# %% [markdown]
# Removendo linhas pelo index
# ```
# df.drop([0, 1])
# ```
# Removendo colunas utilizando o argumento axis=1
# ```
# df.drop('País', axis=1)
# ```

# %%
df = pd.concat([df['members'].apply(pd.Series), df.drop('members', axis = 1)], axis = 1)
df
# Out:
#               name      age secretIdentity  \
# 0     Molecule Man       29      Dan Jukes
# 1  Madame Uppercut       39    Jane Wilson
# 2    Eternal Flame  1000000        Unknown
#
#                                               powers         squadName  \
# 0  [Radiation resistance, Turning tiny, Radiation...  Super Hero Squad
# 1  [Million tonne punch, Damage resistance, Super...  Super Hero Squad
# 2  [Immortality, Heat Immunity, Inferno, Teleport...  Super Hero Squad
#
#      homeTown  formed   secretBase  active
# 0  Metro City    2016  Super tower    True
# 1  Metro City    2016  Super tower    True
# 2  Metro City    2016  Super tower    True

# %% [markdown]
# ### CSV

# %%
notas = pd.read_csv("ratings.csv")
notas.head()
# Out:
#    userId  movieId  rating  timestamp
# 0       1        1     4.0  964982703
# 1       1        3     4.0  964981247
# 2       1        6     4.0  964982224
# 3       1       47     5.0  964983815
# 4       1       50     5.0  964982931

# %%
notas.shape
# Out:
# (100836, 4)

# %%
notas.columns
# Out:
# Index(['userId', 'movieId', 'rating', 'timestamp'], dtype='object')

# %%
listaColunas = list(notas.columns)
listaColunas[2] = "avaliação"
listaColunas
# Out:
# ['userId', 'movieId', 'avaliação', 'timestamp']

# %%
notas.columns = listaColunas
notas
# Out:
#         userId  movieId  avaliação   timestamp
# 0            1        1        4.0   964982703
# 1            1        3        4.0   964981247
# 2            1        6        4.0   964982224
# 3            1       47        5.0   964983815
# 4            1       50        5.0   964982931
# ...        ...      ...        ...         ...
# 100831     610   166534        4.0  1493848402
# 100832     610   168248        5.0  1493850091
# 100833     610   168250        5.0  1494273047
# 100834     610   168252        5.0  1493846352
# 100835     610   170875        3.0  1493846415
#
# [100836 rows x 4 columns]

# %%
notas.columns = ["usuarioId", "filmeId", "nota", "momento"]
notas.head()
# Out:
#    usuarioId  filmeId  nota    momento
# 0          1        1   4.0  964982703
# 1          1        3   4.0  964981247
# 2          1        6   4.0  964982224
# 3          1       47   5.0  964983815
# 4          1       50   5.0  964982931

# %%
notas['nota'].unique()
# Out:
# array([4. , 5. , 3. , 2. , 1. , 4.5, 3.5, 2.5, 0.5, 1.5])

# %%
notas['nota'].value_counts()
# Out:
# nota
# 4.0    26818
# 3.0    20047
# 5.0    13211
# 3.5    13136
# 4.5     8551
# 2.0     7551
# 2.5     5550
# 1.0     2811
# 1.5     1791
# 0.5     1370
# Name: count, dtype: int64

# %%
#contagem de dados não-nulos
notas.count()
# Out:
# usuarioId    100836
# filmeId      100836
# nota         100836
# momento      100836
# dtype: int64

# %%
notas['nota'].mean()
# Out:
# 3.501556983616962

# %%
notas.nota.head()
# Out:
# 0    4.0
# 1    4.0
# 2    4.0
# 3    5.0
# 4    5.0
# Name: nota, dtype: float64

# %%
notas.nota.tail()
# Out:
# 100831    4.0
# 100832    5.0
# 100833    5.0
# 100834    5.0
# 100835    3.0
# Name: nota, dtype: float64

# %%
notas.nota.describe()
# Out:
# count    100836.000000
# mean          3.501557
# std           1.042529
# min           0.500000
# 25%           3.000000
# 50%           3.500000
# 75%           4.000000
# max           5.000000
# Name: nota, dtype: float64

# %%
notas.describe()
# Out:
#            usuarioId        filmeId           nota       momento
# count  100836.000000  100836.000000  100836.000000  1.008360e+05
# mean      326.127564   19435.295718       3.501557  1.205946e+09
# std       182.618491   35530.987199       1.042529  2.162610e+08
# min         1.000000       1.000000       0.500000  8.281246e+08
# 25%       177.000000    1199.000000       3.000000  1.019124e+09
# 50%       325.000000    2991.000000       3.500000  1.186087e+09
# 75%       477.000000    8122.000000       4.000000  1.435994e+09
# max       610.000000  193609.000000       5.000000  1.537799e+09

# %%
notas.dtypes
# Out:
# usuarioId      int64
# filmeId        int64
# nota         float64
# momento        int64
# dtype: object

# %%
notas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100836 entries, 0 to 100835
# Data columns (total 4 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   usuarioId  100836 non-null  int64
#  1   filmeId    100836 non-null  int64
#  2   nota       100836 non-null  float64
#  3   momento    100836 non-null  int64
# dtypes: float64(1), int64(3)
# memory usage: 3.1 MB

# %%
notas[['usuarioId', 'filmeId']]
# Out:
#         usuarioId  filmeId
# 0               1        1
# 1               1        3
# 2               1        6
# 3               1       47
# 4               1       50
# ...           ...      ...
# 100831        610   166534
# 100832        610   168248
# 100833        610   168250
# 100834        610   168252
# 100835        610   170875
#
# [100836 rows x 2 columns]

# %%
filmes = pd.read_csv("movies.csv")
filmes.columns = ["filmeId", "titulo", "generos"]
filmes.head()
# Out:
#    filmeId                              titulo  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                        generos
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
filmes.shape
# Out:
# (9742, 3)

# %%
notas.query("filmeId==1")
# Out:
#        usuarioId  filmeId  nota     momento
# 0              1        1   4.0   964982703
# 516            5        1   4.0   847434962
# 874            7        1   4.5  1106635946
# 1434          15        1   2.5  1510577970
# 1667          17        1   4.5  1305696483
# ...          ...      ...   ...         ...
# 97364        606        1   2.5  1349082950
# 98479        607        1   4.0   964744033
# 98666        608        1   2.5  1117408267
# 99497        609        1   3.0   847221025
# 99534        610        1   5.0  1479542900
#
# [215 rows x 4 columns]

# %%
notas.query("filmeId==1").nota.mean()
# Out:
# 3.9209302325581397

# %%
filtro=notas.query("filmeId==1")
filtro
# Out:
#        usuarioId  filmeId  nota     momento
# 0              1        1   4.0   964982703
# 516            5        1   4.0   847434962
# 874            7        1   4.5  1106635946
# 1434          15        1   2.5  1510577970
# 1667          17        1   4.5  1305696483
# ...          ...      ...   ...         ...
# 97364        606        1   2.5  1349082950
# 98479        607        1   4.0   964744033
# 98666        608        1   2.5  1117408267
# 99497        609        1   3.0   847221025
# 99534        610        1   5.0  1479542900
#
# [215 rows x 4 columns]

# %%
notas.query("filmeId==2").nota.mean()
# Out:
# 3.4318181818181817

# %%
medias_por_filme = notas.groupby("filmeId").mean().nota
medias_por_filme.head()
# Out:
# filmeId
# 1    3.920930
# 2    3.431818
# 3    3.259615
# 4    2.357143
# 5    3.071429
# Name: nota, dtype: float64

# %%
type(medias_por_filme)
# Out:
# pandas.core.series.Series

# %%
medias_por_filme.describe()
# Out:
# count    9724.000000
# mean        3.262448
# std         0.869874
# min         0.500000
# 25%         2.800000
# 50%         3.416667
# 75%         3.911765
# max         5.000000
# Name: nota, dtype: float64

# %%
filmes
# Out:
#       filmeId                                     titulo  \
# 0           1                           Toy Story (1995)
# 1           2                             Jumanji (1995)
# 2           3                    Grumpier Old Men (1995)
# 3           4                   Waiting to Exhale (1995)
# 4           5         Father of the Bride Part II (1995)
# ...       ...                                        ...
# 9737   193581  Black Butler: Book of the Atlantic (2017)
# 9738   193583               No Game No Life: Zero (2017)
# 9739   193585                               Flint (2017)
# 9740   193587        Bungo Stray Dogs: Dead Apple (2018)
# 9741   193609        Andrew Dice Clay: Dice Rules (1991)
#
#                                           generos
# 0     Adventure|Animation|Children|Comedy|Fantasy
# 1                      Adventure|Children|Fantasy
# 2                                  Comedy|Romance
# 3                            Comedy|Drama|Romance
# 4                                          Comedy
# ...                                           ...
# 9737              Action|Animation|Comedy|Fantasy
# 9738                     Animation|Comedy|Fantasy
# 9739                                        Drama
# 9740                             Action|Animation
# 9741                                       Comedy
#
# [9742 rows x 3 columns]

# %%
# Merge - Dataframe Notas com nome do filme
df_notas_com_titulo = pd.merge(
    notas,
    filmes[['filmeId', 'titulo']],  # pegando só as colunas necessárias
    on='filmeId',
    how='left'
)
df_notas_com_titulo
# Out:
#         usuarioId  filmeId  nota     momento                          titulo
# 0               1        1   4.0   964982703                Toy Story (1995)
# 1               1        3   4.0   964981247         Grumpier Old Men (1995)
# 2               1        6   4.0   964982224                     Heat (1995)
# 3               1       47   5.0   964983815     Seven (a.k.a. Se7en) (1995)
# 4               1       50   5.0   964982931      Usual Suspects, The (1995)
# ...           ...      ...   ...         ...                             ...
# 100831        610   166534   4.0  1493848402                    Split (2017)
# 100832        610   168248   5.0  1493850091   John Wick: Chapter Two (2017)
# 100833        610   168250   5.0  1494273047                  Get Out (2017)
# 100834        610   168252   5.0  1493846352                    Logan (2017)
# 100835        610   170875   3.0  1493846415  The Fate of the Furious (2017)
#
# [100836 rows x 5 columns]

# %%
df_notas_com_titulo = df_notas_com_titulo[['usuarioId', 'titulo', 'nota', 'momento']]
df_notas_com_titulo
# Out:
#         usuarioId                          titulo  nota     momento
# 0               1                Toy Story (1995)   4.0   964982703
# 1               1         Grumpier Old Men (1995)   4.0   964981247
# 2               1                     Heat (1995)   4.0   964982224
# 3               1     Seven (a.k.a. Se7en) (1995)   5.0   964983815
# 4               1      Usual Suspects, The (1995)   5.0   964982931
# ...           ...                             ...   ...         ...
# 100831        610                    Split (2017)   4.0  1493848402
# 100832        610   John Wick: Chapter Two (2017)   5.0  1493850091
# 100833        610                  Get Out (2017)   5.0  1494273047
# 100834        610                    Logan (2017)   5.0  1493846352
# 100835        610  The Fate of the Furious (2017)   3.0  1493846415
#
# [100836 rows x 4 columns]

# %% [markdown]
# ### Excel

# %%
idades = pd.read_excel("idades.xlsx", sheet_name="Planilha2")
idades.head()
# Out:
#           Nome  Idade
# 0       Agatha     24
# 1        Alice     27
# 2       Alícia     18
# 3       Amanda     18
# 4  Ana Beatriz     44

# %% [markdown]
# ### Escrevendo em um CSV
# #### Biblioteca csv

# %%
import csv

# Lista de artistas e links (exemplo similar ao scraping feito no código original)
data = [
    ['Artist 1', 'https://example.com/artist1'],
    ['Artist 2', 'https://example.com/artist2'],
    ['Artist 3', 'https://example.com/artist3']
]

# Abre (ou cria) o arquivo CSV para escrita
with open('artist_names.csv', mode='w', newline='', encoding='utf-8') as file:
    writer = csv.writer(file)
    
    # Escreve o cabeçalho
    writer.writerow(['Name', 'Link'])
    
    # Escreve as linhas dos dados
    writer.writerows(data)

print("Arquivo CSV salvo com sucesso.")
# Out:
# Arquivo CSV salvo com sucesso.

# %% [markdown]
# #### Biblioteca Pandas

# %%
import pandas as pd

# Lista de artistas e links (exemplo similar ao scraping feito no código original)
data = {
    'Name': ['Artist 1', 'Artist 2', 'Artist 3'],
    'Link': ['https://example.com/artist1', 'https://example.com/artist2', 'https://example.com/artist3']
}

# Cria um DataFrame com os dados
df = pd.DataFrame(data)

# Salva o DataFrame em um arquivo CSV
df.to_csv('artist_names.csv', index=False)

print("Arquivo CSV salvo com sucesso.")
# Out:
# Arquivo CSV salvo com sucesso.

# %% [markdown]
# ### Escrevendo em um XLSX

# %%
import pandas as pd

# Lista de artistas e links (exemplo similar ao scraping feito no código original)
data = {
    'Name': ['Artist 1', 'Artist 2', 'Artist 3'],
    'Link': ['https://example.com/artist1', 'https://example.com/artist2', 'https://example.com/artist3']
}

# Cria um DataFrame com os dados
df = pd.DataFrame(data)

# Salva o DataFrame em um arquivo Excel
df.to_excel('artist_names.xlsx', index=False)

print("Arquivo Excel salvo com sucesso.")
# Out:
# Arquivo Excel salvo com sucesso.
