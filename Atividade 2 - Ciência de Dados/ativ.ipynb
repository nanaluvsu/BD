# %%
import pandas as pd

# %% [markdown]
# # 1.  Importe a biblioteca pandas, leia os arquivos CSV e carregue-os em DataFrames

# %%
df_b = pd.read_csv("books.csv")
df_r = pd.read_csv("ratings.csv")
df_tr = pd.read_csv("to_read.csv")

df_b.head()
